# %% [markdown]
# ### 바뀐부분
# - Brunch 가즈아~!!

# %%
import pandas as pd
import numpy as np

from collections import Counter
from datetime import timedelta, datetime
import glob
import itertools
from itertools import chain
import json
import os
import re

import matplotlib.pyplot as plt
# import seaborn as sns
import gc

import os
import random
from abc import *

from tqdm import tqdm_notebook

# %% [markdown]
# # Modeling

# %%
class AbstractRecommend(metaclass=ABCMeta):
    
    def __init__(self):
        pass
    
    @abstractmethod
    def recommend(self):
        pass
    
    def calculate_recommend(self, frame, before_recommend_count, cutoff_recommend_count):
        
        limit_recommend = 100 - before_recommend_count
        # 마지막 모델이거나 cutoff 제한이 없는 경우에는 100-recommend의 개수까지 추천합니다.
        if self.last_model is True or cutoff_recommend_count is -1:
            return frame['article_id'].values[:limit_recommend].tolist()
        
        # 설정한 cutoff 보다 추천대상이 작으면 frame article_id를 그대로 return합니다.
        if frame.shape[0] < cutoff_recommend_count:
            return frame['article_id'].values.tolist()

        # cutoff 보다 추천할 대상이 많으면 cutoff만큼 추천합니다.
        return frame['article_id'].values[:cutoff_recommend_count].tolist()

# %%
class RandomBestRecommend(AbstractRecommend):
    def __init__(self, recommend_frame, cutoff_recommend_count):
        self.recommend_frame = recommend_frame
        self.cutoff_recommend_count = cutoff_recommend_count
        self.last_model = False
        
    def set_last_model(self):
        self.last_model = True
        
    def recommend(self, read_list, user_id, before_recommend_count):
        frame = self.recommend_frame.query("article_id not in @read_list")

        limit_recommend = 100 - before_recommend_count
        # 마지막 모델이거나 cutoff 제한이 없는 경우에는 100-recommend의 개수까지 추천합니다.
        if self.last_model is True or self.cutoff_recommend_count is -1:
            return frame['article_id'].values[:limit_recommend].tolist()
        
        # 설정한 cutoff 보다 추천대상이 작으면 frame article_id를 그대로 return합니다.
        recommend_count = min(limit_recommend, self.cutoff_recommend_count)
        if frame.shape[0] < recommend_count:
            return frame['article_id'].values.tolist()

        # cutoff 보다 추천할 대상이 많으면 cutoff만큼 추천합니다.
        return frame['article_id'].values[:recommend_count].tolist() 

class BrunchRecommend(AbstractRecommend):  
    def __init__(self, user_list, read_frame, read_set=None):
        self.user_list = user_list
        self.read_dict = read_frame.groupby('user_id')['article_id'].apply(list).to_dict()
        self.recommend_result = dict()
        #self.recommend_mixed_result = dict()
        self.all_read_set = set()
        if read_set is not None:
            self.all_read_set = read_set.copy()
    
    def make_result_frame(self):
        temp = pd.DataFrame.from_dict(self.recommend_result).T.reset_index()
        return temp.rename(columns={'index':'user_id'})
    
    def recommend(self, model_list=None):
        try:
            if not model_list:
                raise Exception("model_list는 적어도 한 개 이상 있어야 합니다.")
            
            model_list[-1].set_last_model()
            
            self.recommend_result.clear()
            #self.recommend_mixed_result.clear()
            for user in tqdm_notebook(self.user_list):
                self.recommend_result[user] = list()
                #self.recommend_mixed_result[user] = list()
                # read file에서 user가 이미 읽은 것을 제외합니다.
                try:
                    already_user_read = self.read_dict[user]
                except KeyError as e:
                    already_user_read = []
                
                # model_list를 전달받으면 전달받은 model_list로 추천을 합니다.
                for model in model_list:
                    
                    # 각 모델마다 recommend를 수행합니다.
                    if isinstance(model, RandomBestRecommend) is True:
                        print("RandomBestRecommend")
                        read_list = list(self.all_read_set) + already_user_read
                        r = model.recommend(read_list, user, len(self.recommend_result[user]))
                        print(len(r))
                    else:
                        # user가 읽은 list와 이미 추천했던 결과를 합쳐서 model이 제외할 list를 만듭니다.
                        read_list = self.recommend_result[user].copy()
                        read_list = read_list + already_user_read
                        read_list = list(set(read_list))
                        r = model.recommend(read_list, user, len(self.recommend_result[user]))
                    
                    # recommend
                    self.recommend_result[user] = self.recommend_result[user] + r
                    self.all_read_set = self.all_read_set.union(set(r))
                    #self.recommend_mixed_result[user].append(r)
                    
        except Exception as e:
            print(e)
            raise
            
    def _ndcg(self):
        pass
    def _map(self):
        pass
    def _entropy_diversity(self):
        pass
    def evaluate(self):
        pass

class TimebasedRecommend(AbstractRecommend):
    def __init__(self, user_frame, timebased_frame, cutoff_recommend_count):
        self.timebased_frame = timebased_frame
        self.user_frame = user_frame
        self.cutoff_recommend_count = cutoff_recommend_count
        self.last_model = False
    
    def set_last_model(self):
        self.last_model = True
        
    def recommend(self, read_list, user_id, before_recommend_count):
        user_frame = self.user_frame.loc[self.user_frame['user_id']==user_id]
        from_list = sorted(user_frame['from'].unique())
        if len(from_list) == 0:
            return list()
        
        frame = self.timebased_frame.query("article_id not in @read_list")
        
        frame_list = []
        for t in from_list:
            temp = frame.loc[frame['dt']==t].reset_index(drop=True)
            temp['index'] = range(temp.shape[0])
            frame_list.append(temp)
        
        frame = pd.concat(frame_list)
        frame = frame.sort_values(['index','count'], ascending=[True,False])
        frame = frame.drop_duplicates('article_id', keep='first')
        # 최대 recommend limit를 설정합니다.
        
        limit_recommend = 100 - before_recommend_count
        # 마지막 모델이거나 cutoff 제한이 없는 경우에는 100-recommend의 개수까지 추천합니다.
        if self.last_model is True or self.cutoff_recommend_count is -1:
            return frame['article_id'].values[:limit_recommend].tolist()
        
        # 설정한 cutoff 보다 추천대상이 작으면 frame article_id를 그대로 return합니다.
        recommend_count = min(limit_recommend, self.cutoff_recommend_count)
        if frame.shape[0] < recommend_count:
            return frame['article_id'].values.tolist()

        # cutoff 보다 추천할 대상이 많으면 cutoff만큼 추천합니다.
        return frame['article_id'].values[:recommend_count].tolist() 
        
class CutoffRecommend(AbstractRecommend):
    """
    Cutoff를 가지는 recommend 모델입니다.
    AbstractRecommend를 상속받는 모델은 recommend 함수를 구현해야 합니다.
    
    recommend_frame: 각 추천 모델마다 필요한 전처리된 추천 frame입니다.
    cutoff_recommend_count: 각 모델마다 cutoff값, -1로 설정하면 cutoff 제한이 없이 100 - 이전 모델 추천 개수 까지 추천합니다.
    continous_read: True면 flag_sum을 가지는 연속형 추천 모델이고, False면 flag_sum을 가지지 않는 모델입니다.
    
    기존 현우님 모델은 flag_sum_1,2,3,4,5 라고 되어있었는데 이것을 flag_sum이라는 컬럼에 1,2,3,4,5..n을 추가하는 형태로 변경합니다.
    flag_sum은 반드시 높은 숫자가 좋아야 합니다.
    """
    def __init__(self, recommend_frame, cutoff_recommend_count, userbased_model=True, continous_read=False):
        
        self.recommend_frame = recommend_frame
        self.cutoff_recommend_count = cutoff_recommend_count
        self.continous_read = continous_read
        self.userbased_model = userbased_model
        self.last_model = False
    
    def set_last_model(self):
        self.last_model = True
        
    def recommend(self, read_list, user_id, before_recommend_count):
        """
        parameter
        read_list: 이전 모델까지 추천한 article과 2/22 ~ 3/1일 까지의 읽은 article
        user_id: user별로 추천하는 모델은 user_id를 넘겨줘야 합니다.
        before_count: 이전 모델까지의 추천 개수
        
        return
        list형태의 article_id
        """
        
        # 이전에 추천했던 article을 제거합니다.
        #frame = self.recommend_frame.loc[~self.recommend_frame['article_id'].isin(read_list)]

        # user_id를 사용하는 모델은 해당 user_id만 가져옵니다.
        if self.userbased_model is True:
            frame = self.recommend_frame.query("user_id == @user_id")
            frame = frame.query("article_id not in @read_list")
        else:
            frame = self.recommend_frame.query("article_id not in @read_list")
        
        # flag_sum이 포함된 모델, 연속 추천 모델
        if self.continous_read is True:
            # flag_sum은 높은것이 좋기 때문에 내림차순, count도 높은것이 좋기 때문에 내림차순
            frame = frame.sort_values(by=['flag_sum', 'count'], ascending=[False, False])
            
        limit_recommend = 100 - before_recommend_count
        # 마지막 모델이거나 cutoff 제한이 없는 경우에는 100-recommend의 개수까지 추천합니다.
        if self.last_model is True or self.cutoff_recommend_count is -1:
            return frame['article_id'].values[:limit_recommend].tolist()
        
        # 설정한 cutoff 보다 추천대상이 작으면 frame article_id를 그대로 return합니다.
        recommend_count = min(limit_recommend, self.cutoff_recommend_count)
        if frame.shape[0] < recommend_count:
            return frame['article_id'].values.tolist()

        # cutoff 보다 추천할 대상이 많으면 cutoff만큼 추천합니다.
        return frame['article_id'].values[:recommend_count].tolist()

# %% [markdown]
# ### rowwise read 만드는 부분 / 전처리되어 있으면 실행안해도 됩니다.

# %% [markdown]
# #### Make Read Frame
# https://arena.kakao.com/forum/topics/10 <br>
# tip! dataframe 선언해서 loop안에서 concat하면 엄청느린데 list에 append 후 concat하니 훨씬 빠름

# %%
# input_read_path = 'res/read/'
# file_list = os.listdir(input_read_path)

# file_list = [f for f in file_list if len(f.strip().split('.')) == 1]

# read_df_list = []
# for file in tqdm_notebook(file_list):
#     file_path = input_read_path + file
#     df_temp = pd.read_csv(file_path, header=None, names=['raw'])
#     df_temp['from'] = file.split('_')[0]
#     df_temp['to'] = file.split('_')[1]
#     read_df_list.append(df_temp)
    
# read_df = pd.concat(read_df_list)

# read_df['user_id'] = read_df['raw'].apply(lambda x: x.split(' ')[0])
# read_df['article_id'] = read_df['raw'].apply(lambda x: x.split(' ')[1:])

# def chainer(s):
#     return list(itertools.chain.from_iterable(s))

# read_cnt_by_user = read_df['article_id'].map(len)
# read_rowwise = pd.DataFrame({'from': np.repeat(read_df['from'], read_cnt_by_user),
#                          'to': np.repeat(read_df['to'], read_cnt_by_user),
#                          'user_id': np.repeat(read_df['user_id'], read_cnt_by_user),
#                          'article_id': chainer(read_df['article_id'])})

# #read_rowwise = read_rowwise.loc[read_rowwise['article_id']!='']
# read_rowwise.reset_index(drop=True, inplace=True)

# read_rowwise.to_csv('res/read_rowwise_v2.csv', index=False)

# %% [markdown]
# ### Make Recommend Frame Func

# %%
def get_how_many_read_by_eachuser(read):
    """
    eda_table
    how_many_read_by_eachuser = pd.DataFrame(read.groupby(['user_id'])['author_id'].value_counts())
    how_many_read_by_eachuser.columns = ['count']
    how_many_read_by_eachuser = how_many_read_by_eachuser.reset_index()
    """
    how_many_read_by_eachuser = pd.DataFrame(read.groupby(['user_id'])['author_id'].value_counts())
    how_many_read_by_eachuser.columns = ['count']
    how_many_read_by_eachuser = how_many_read_by_eachuser.reset_index()
    return how_many_read_by_eachuser

def get_how_many_write(read):
    """
    eda_table1
    how_many_write_df = pd.DataFrame(read.groupby(['author_id'])['article_id'].agg({'nunique'}))
    how_many_write_df.columns = ['author_article_write_cnt']
    how_many_write_df = how_many_write_df.reset_index()
    """
    how_many_write_df = pd.DataFrame(read.groupby(['author_id'])['article_id'].agg({'nunique'}))
    how_many_write_df.columns = ['author_article_write_cnt']
    how_many_write_df = how_many_write_df.reset_index()
    return how_many_write_df

def get_how_many_read_repeat(read):
    """
    eda_table2
    how_many_read_repeat_df = pd.DataFrame(read.groupby(['user_id','author_id'])['dt'].agg({'nunique'}))
    how_many_read_repeat_df.columns = ['count']
    how_many_read_repeat_df = how_many_read_repeat_df.reset_index()
    """
    how_many_read_repeat_df = pd.DataFrame(read.groupby(['user_id','author_id'])['dt'].agg({'nunique'}))
    how_many_read_repeat_df.columns = ['count']
    how_many_read_repeat_df = how_many_read_repeat_df.reset_index()
    return how_many_read_repeat_df

def get_how_many_read_each_article_by_eachuser(read):
    """
    eda_table4 = pd.DataFrame(df_table.groupby(['user_id','author_id'])['article_id'].agg({'nunique'}))
    eda_table4.columns = ['count']
    eda_table4 = eda_table4.reset_index()
    """
    how_many_read_each_article_by_eachuser = pd.DataFrame(read.groupby(['user_id','author_id'])['article_id'].agg({'nunique'}))
    how_many_read_each_article_by_eachuser.columns = ['count']
    how_many_read_each_article_by_eachuser = how_many_read_each_article_by_eachuser.reset_index()
    return how_many_read_each_article_by_eachuser    

def get_how_many_read(read):
    """
    sub_table
    how_many_read = pd.DataFrame(read['article_id'].value_counts()).reset_index()
    how_many_read.columns = ['article_id','count']
    how_many_read['author_id'] = how_many_read['article_id'].astype(str).apply(lambda x: x.split('_')[0])
    """
    how_many_read = pd.DataFrame(read['article_id'].value_counts()).reset_index()
    how_many_read.columns = ['article_id','count']
    how_many_read['author_id'] = how_many_read['article_id'].astype(str).apply(lambda x: x.split('_')[0])
    return how_many_read

def get_how_many_read_by_variableuser_author(read):
    """
    sub_table1
    temp = pd.DataFrame(read.groupby('author_id')['user_id'].agg({'nunique'})).reset_index()
    temp.columns = ['author_id','nunique']
    """
    temp = pd.DataFrame(read.groupby('author_id')['user_id'].agg({'nunique'})).reset_index()
    temp.columns = ['author_id','nunique']
    return temp

def get_how_many_read_by_variableuser_article(read):
    """
    sub_table2
    temp = pd.DataFrame(read.groupby('article_id')['user_id'].agg({'nunique'})).reset_index()
    temp.columns = ['article_id','nunique']
    temp = temp.sort_values(by='nunique',ascending=False)
    """
    temp = pd.DataFrame(read.groupby('article_id')['user_id'].agg({'nunique'})).reset_index()
    temp.columns = ['article_id','nunique']
    temp = temp.sort_values(by='nunique',ascending=False)
    return temp

def recent_following_article(following_favor, col1, col2):
    # groupby sort_values 순서가 ascending=True라서 -1곱해서 바꿔줌. 
    following_favor['count'] = following_favor[col1] * -1 / following_favor[col2]
    
    # count는 내림차순(-1을 곱한 상태에서 내림차순), reg_dt는 오름차순으로 되는데 =>  
    following_favor = following_favor.groupby(['user_id', 'count']).apply(lambda x: x.sort_values(by ='diffday_from_end')).reset_index(drop=True)
    following_favor['count'] = following_favor['count'] * -1
    return following_favor

def read_preprocessing(read_data, metadata, read_period):
    # period는 (] 형식으로 start날짜는 포함하고 end날짜는 포함하지 않는다.
    read_cutoff_start = read_period[0] # begin
    read_cutoff_end = read_period[1] # end
    read_index = (read_data['dt'] >= read_cutoff_start) & (read_data['dt'] < read_cutoff_end)
    
    read = read_data.loc[read_index] # read cut off
    read = read.loc[read['article_id'].isin(metadata['id'])] # meta에 없는 read 제거
    read['author_id'] = read['article_id'].astype(str).apply(lambda x: x.split('_')[0])
    return read

def meta_preprocessing(metadata, meta_period, use_megazine=False, use_regdt=False):
    """
    selected_column = ['following_id', 'article_id', 'diffday_from_end']
    if use_megazine is True:
        selected_column = ['following_id','article_id','magazine_id','diffday_from_end']
    if use_regdt is True:
        selected_column = selected_column + ['reg_dt']
    """
    # period는 (] 형식으로 start날짜는 포함하고 end날짜는 포함하지 않는다.
    meta_cutoff_start = meta_period[0] # begin
    meta_cutoff_end = meta_period[1] # end
    meta_cutoff_index = (pd.to_datetime(metadata['reg_dt']) >= meta_cutoff_start) & (pd.to_datetime(metadata['reg_dt']) < meta_cutoff_end)
    
    new_meta = metadata.loc[meta_cutoff_index]
    new_meta['diffday_from_end'] = (meta_cutoff_end - pd.to_datetime(new_meta['reg_dt'])).dt.days
    
    # column rename
    del new_meta['article_id']
    new_meta.rename(columns={'user_id':'following_id','id':'article_id'}, inplace=True)
    
    # select column
    selected_column = ['following_id', 'article_id', 'diffday_from_end']
    if use_megazine is True:
        selected_column = ['following_id','article_id','magazine_id','diffday_from_end']
    if use_regdt is True:
        selected_column = selected_column + ['reg_dt']
    new_meta = new_meta[selected_column]
    return new_meta
    
def rank_preprocessing(following_favor):
    following_favor_null = following_favor.loc[following_favor['rank'].isnull()].reset_index(drop=True)
    following_favor_not_null = following_favor.loc[following_favor['rank'].notnull()].reset_index(drop=True)
    
    # 3월 글
    following_favor_null = following_favor_null.loc[following_favor_null['diffday_from_end']<=15]
    
    # 많이 읽힌글 가져오기
    following_favor_not_null = following_favor_not_null.loc[following_favor_not_null['rank']<10].reset_index(drop=True)
    
    temp = pd.concat([following_favor_null,following_favor_not_null], axis=0)
    return temp

# %%
# 유저별 선호도가 보정된 데이터를 추출하기 위한 함수
def count_correlction_read_favor(read_data, metadata, user_id_frame,
                                 meta_period=(pd.datetime(2019, 2, 14), pd.datetime(2019, 3, 15)), 
                                 read_period=(20190214, 20190301),
                                 favor_cutoff=0.05 ):
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)

    # meta 전처리
    new_meta = meta_preprocessing(metadata, meta_period, use_megazine=True)
    new_meta['diffday_from_end'] = new_meta['diffday_from_end']-14
    new_meta = new_meta.loc[new_meta['diffday_from_end'] > 0]
    new_meta['diffday_from_end'] = new_meta['diffday_from_end'].apply(lambda x: 15 if x >= 15 else x)
    
    # sub_table article이 얼마나 많이 읽혔는지, return ['article_id', 'count', 'author_id']
    sub_table = get_how_many_read(read) 
    sub_table.rename(columns={'count':'how_many_read'}, inplace=True)

    # eda_table user별로 작가의 글을 몇번 읽었는지, return ['user_id', 'author_id', 'count']
    eda_table = get_how_many_read_by_eachuser(read) 

    # eda_table1 작가가 글을 몇개 썼는지 ['author_id', 'article_id', 'author_article_write_cnt']
    eda_table1 = get_how_many_write(read) 
    
    # eda_tabl4 user별로 작가의 글을 얼마나 다양하게 읽었는데 reuturn ['user_id', 'author_id', 'count']
    eda_table4 = get_how_many_read_each_article_by_eachuser(read) 

    # sub_table1 작가의 글을 다양한 유저가 읽었는지 ['author_id', 'user_id', 'nunique']
    sub_table1 = get_how_many_read_by_variableuser_author(read) # sub_table1
    
    df_table1 = pd.merge(eda_table4, sub_table, on='author_id') #eda_table: 유저가 author_id의 글을 몇번 봤는지 # eda_table4 : 유저가 author_id의 글을 몇개나 봤는지 
    df_table1 = pd.merge(df_table1, sub_table1, on='author_id') #sub_table1 :author_id별로 글을 읽는 user는 몇명인지
    #df_table1 = pd.merge(df_table1, eda_table1, on='author_id', how='left') #sub_table1 : author_id별로 글을 읽는 user는 몇명인지
    df_table1 = pd.merge(df_table1, new_meta, on='article_id', how='left')
    
    df_table1['correction_count'] = (df_table1['count'] * df_table1['how_many_read'])/(df_table1['nunique']) #nunique: 이 작가의 글을 읽는 사람의 수 <- ??
    
    df_table2 = df_table1.sort_values(by='correction_count' ,ascending=False)
    df_table3 = df_table2[['user_id','article_id','correction_count']]
    df_table3 = df_table3.dropna(axis=0)
    
    dev1 = user_id_frame.merge(df_table3, on='user_id', how='left')
    dev2 = dev1.groupby('user_id')['user_id'].agg({'size'}).reset_index().sort_values('size')
    dev1 = pd.merge(dev1, dev2, how='left',on='user_id')
    
    read_user = dev1.loc[(dev1['correction_count'].notnull())]
    dontread_user = dev1.loc[(dev1['correction_count'].isnull())]
    read_user = read_user.loc[read_user['correction_count'] > read_user['correction_count'].quantile(favor_cutoff)]
    print("read_user", read_user.shape)
    print("dontread_user", dontread_user.shape)
    return read_user, dontread_user

# %%
# 구독자 선호도
def following_favor_frame(read_data, metadata, following_table, best, 
                          correction_type=0,
                          meta_period=(pd.datetime(2019, 2, 22), pd.datetime(2019, 3, 15)), 
                          read_period=(20190214, 20190301),
                          favor_cutoff=0.05):
    
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)
    
    # meta 전처리
    new_meta = meta_preprocessing(metadata, meta_period)

    # 내가 구독하는 작가의 글 중에서 최신글
    following_favor = following_table.copy()
    following_favor = pd.merge(following_favor, new_meta, how='left', on='following_id')
    following_favor = following_favor.loc[following_favor['article_id']!='']
    following_favor = following_favor.loc[following_favor['following_id']!='']
    following_favor = following_favor.dropna(axis=0)
    following_favor.columns = ['user_id', 'author_id', 'article_id', 'diffday_from_end']
    
    # count 보정을 위한 read에서 통계값 구하기
    if correction_type == 0:
        correction_df1 = get_how_many_read_by_eachuser(read)
    elif correction_type == 1:
        correction_df1 = get_how_many_read_repeat(read)
    else :
        correction_df1 = get_how_many_read_each_article_by_eachuser(read)
        
    how_many_write_df = get_how_many_write(read)
    
    following_favor = following_favor.merge(correction_df1, how='left', on=['user_id','author_id'])
    following_favor = following_favor.merge(how_many_write_df, how='left', on=['author_id'])
    following_favor = following_favor.merge(best, how='left',on=['article_id','author_id'])
    following_favor = following_favor[following_favor['count'].notnull()]
    
    # read count 보정 후, 최근 article sort
    following_favor = recent_following_article(following_favor, 'count', 'author_article_write_cnt')
    
    # 하위 5% cutoff
    following_favor = following_favor.loc[following_favor['count'] > following_favor['count'].quantile(favor_cutoff)] 
    # best에서 전달받은 rank 전처리
    following_favor = rank_preprocessing(following_favor)
    # reg_dt가 3월인 부분 제거 
    following_favor = following_favor[following_favor['diffday_from_end'].notnull()].reset_index(drop=True)
    # count로 sort
    following_favor = following_favor.sort_values(by=['count','rank','diffday_from_end'], ascending=[False,True,False])
    return following_favor

# %%
# 구독자 선호도
def dont_following_favor_frame(read_data, metadata, following_table, best, 
                          correction_type=0,
                          meta_period=(pd.datetime(2019, 2, 22), pd.datetime(2019, 3, 15)), 
                          read_period=(20190214, 20190301),
                          favor_cutoff=0.05):
    
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)
    
    # meta 전처리
    new_meta = meta_preprocessing(metadata, meta_period)

    # 구독한 정보를 토대로 구독하지 않은 작가들의 글만 추출할 것임. 
    following = following_table[['user_id','following_id']]
    following = following.drop_duplicates(subset=['user_id','following_id'])
    following['following'] = 1

    # 구독하지 않은 작가의 읽은 정보
    dont_following_favor = pd.DataFrame()
    dont_following_favor['user_id'] = read['user_id']
    dont_following_favor['following_id'] = read['article_id'].apply(lambda x: x.split('_')[0])
    dont_following_favor = pd.merge(dont_following_favor,following,how='left',on=['user_id','following_id'])
    dont_following_favor = dont_following_favor[dont_following_favor['following'].isnull()].reset_index(drop=True)
    del dont_following_favor['following']
    
    # 내가 구독하는 작가의 글 중에서 최신글
    dont_following_favor = pd.merge(dont_following_favor, new_meta, how='left', on='following_id')
    dont_following_favor = dont_following_favor.loc[dont_following_favor['article_id']!='']
    dont_following_favor = dont_following_favor.loc[dont_following_favor['following_id']!='']
    dont_following_favor = dont_following_favor.dropna(axis=0)
    dont_following_favor.columns = ['user_id', 'author_id', 'article_id', 'diffday_from_end']
    dont_following_favor = dont_following_favor.drop_duplicates(['user_id','article_id'])

    # count 보정을 위한 read에서 통계값 구하기
    if correction_type == 0:
        correction_df1 = get_how_many_read_by_eachuser(read)
    elif correction_type == 1:
        correction_df1 = get_how_many_read_repeat(read)
    else :
        correction_df1 = get_how_many_read_each_article_by_eachuser(read)
        
    how_many_write_df = get_how_many_write(read)
    
    dont_following_favor = dont_following_favor.merge(correction_df1, how='left', on=['user_id','author_id'])
    dont_following_favor = dont_following_favor.merge(how_many_write_df, how='left', on=['author_id'])
    dont_following_favor = dont_following_favor.merge(best, how='left',on=['article_id','author_id'])
    dont_following_favor = dont_following_favor[dont_following_favor['count'].notnull()]
    
    # read count 보정 후, 최근 article sort
    dont_following_favor = recent_following_article(dont_following_favor, 'count', 'author_article_write_cnt')
    
    # 하위 5% cutoff
    dont_following_favor = dont_following_favor.loc[dont_following_favor['count'] > dont_following_favor['count'].quantile(favor_cutoff)] 
    # best에서 전달받은 rank 전처리
    dont_following_favor = rank_preprocessing(dont_following_favor)
    # reg_dt가 3월인 부분 제거 
    dont_following_favor = dont_following_favor[dont_following_favor['diffday_from_end'].notnull()].reset_index(drop=True)
    # count로 sort
    dont_following_favor = dont_following_favor.sort_values(by=['count','rank','diffday_from_end'], ascending=[False,True,False])
    return dont_following_favor

# %%
def shift_preprocessing(series, groupby_col, series_count):
    new_col_list = []
    for shift_num in range(1, series_count+1):
        new_col = f'lag_readYN_{shift_num}'
        new_col_list.append(new_col)
        series[new_col] = series.groupby(groupby_col)['readYN'].shift(-1*shift_num)
    
    new_readYN_sum_list = []
    for shift_num in range(1, series_count):
        new_col = f'readYN_sum_{shift_num}'
        new_readYN_sum_list.append(new_col)
        
        previous_col = f'readYN_sum_{shift_num-1}'
        if shift_num == 1:
            series[new_col] = series[new_col_list[shift_num]] + series[new_col_list[shift_num-1]]
        else:
            series[new_col] = series[previous_col] + series[new_col_list[shift_num]]
    
    series['flag_sum'] = series[new_readYN_sum_list[1:]].max(axis=1)
    series = series.loc[(series['readYN_sum_1']==2) & (series['readYN']==0)].reset_index(drop=True)
    return series

def get_weekly_metadata(metadata, 
                        meta_period=(pd.datetime(2017, 7, 27), pd.datetime(2019, 3, 15))):
    
    # meta 전처리
    # return ['following_id','article_id','magazine_id','diffday_from_end', 'reg_dt']
    new_meta = meta_preprocessing(metadata, meta_period, use_megazine=True, use_regdt=True)
    new_meta = new_meta.loc[new_meta['magazine_id'] != 0]
    new_meta['reg_dt_dayofweek'] = pd.to_datetime(new_meta['reg_dt']).dt.dayofweek
    
    # 최신것으로 sort
    new_meta = new_meta.sort_values(by='diffday_from_end', ascending=True)
    
    # dayofweek의 unique한 개수
    metadata_weekly = new_meta.groupby(['magazine_id'])['reg_dt_dayofweek'].agg({'nunique'}).reset_index()
    # 3월 15일부터 글을 올린 날짜의 차이의 unique한 개수
    metadata_reg_dt = new_meta.groupby(['magazine_id'])['diffday_from_end'].agg({'nunique'}).reset_index()
    
    metadata_temp = pd.merge(new_meta, metadata_weekly, on='magazine_id', how='left')
    metadata_temp = pd.merge(metadata_temp, metadata_reg_dt, on='magazine_id', how='left')
    
    # *5주 이상동안 같은 날 연재한 글*
    # nunique_x: reg_dt_dayofweek / nunique_y: diffday_from_end
    # 같은날 연재되면서 diffday가 5개 이상이라는 것을 weekly megazine으로 봄
    # 연속적이지 않을 수 있는데, 그것은 따로 판단
    weekly_megazine = metadata_temp.loc[(metadata_temp['nunique_x']==1) & (metadata_temp['nunique_y']>=5)]
    weekly_megazine['weekly'] = 1
    weekly_megazine = weekly_megazine[['magazine_id','article_id','weekly','diffday_from_end']]
    weekly_megazine['following_id'] = weekly_megazine['article_id'].apply(lambda x: x.split('_')[0])
    return weekly_megazine

def weekly_magazine_series(read_data, metadata, following, 
                           meta_period=(pd.datetime(2017,7, 14), pd.datetime(2019, 3, 15)), 
                           read_period=(20190207, 20190301),
                           series_count=6):
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)
    print("read")
    # get weekly article
    weekly_meta = get_weekly_metadata(metadata)
    print("weekly_meta")
    # weekly 매거진 추천도 내가 구독한 작가만 사용
    following_table = following.copy()
    magazine_table = following_table.merge(weekly_meta, on=['following_id'], how='left')
    print("magazine_table")
    # following table이 user_id, following_id / weekly_meta가 'magazine_id','article_id','weekly','diffday_from_end', following_id
    # following_id를 user_id로 변경
    magazine_table.columns = ['user_id','author_id','magazine_id','article_id','weekly','diffday_from_end']
    magazine_table = magazine_table.dropna(axis=0)
    
    check_reading_table = read[['user_id','article_id']] # df_table은 읽은 것만. 
    check_reading_table['readYN'] = 1
    magazine_table = pd.merge(magazine_table, check_reading_table, how='left',on=['user_id','article_id'])
    magazine_table['readYN'] = magazine_table['readYN'].fillna(0)
    
    magazine_table = magazine_table.sort_values(by='diffday_from_end') #날짜 
    magazine_table = magazine_table.drop_duplicates(['user_id','article_id'])
    
    magazine_table = shift_preprocessing(magazine_table, ['user_id','magazine_id'], series_count)
    
    how_many_read = get_how_many_read_by_eachuser(read)
    magazine_table = pd.merge(magazine_table, how_many_read, how='left', on=['user_id','author_id'])
    return magazine_table
    
    
def magazine_series(read_data, metadata, following_table, 
                    meta_period=(pd.datetime(2019, 2, 14), pd.datetime(2019, 3, 15)), 
                    read_period=(20190207, 20190301),
                    series_count=7):
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)
    
    # meta 전처리
    new_meta = meta_preprocessing(metadata, meta_period, use_megazine=True)
    
    following = following_table.copy()
    series_table = pd.merge(following, new_meta, how='left', on='following_id') # 읽은 글하고 안읽은 글이 섞여요. 
    series_table = series_table.loc[series_table['article_id']!='']
    series_table = series_table.loc[series_table['following_id']!='']
    series_table = series_table.dropna(axis=0)
    series_table.columns = ['user_id','author_id','article_id','magazine_id','diffday_from_end']
    
    check_reading_table = read[['user_id','article_id']] # df_table은 읽은 것만. 
    check_reading_table['readYN'] = 1
    series_table = pd.merge(series_table, check_reading_table, how='left',on=['user_id','article_id'])
    series_table['readYN'] = series_table['readYN'].fillna(0)
    
    series_table = series_table.sort_values(by='diffday_from_end') #날짜 
    series_table = series_table.drop_duplicates(['user_id','article_id'])
    
    series_table = shift_preprocessing(series_table, ['user_id','author_id','magazine_id'], series_count)
    
    how_many_read = get_how_many_read_by_eachuser(read)
    series_table = pd.merge(series_table, how_many_read, how='left',on=['user_id','author_id'])
    
    return series_table

# %%
def dont_following_magazine_series(read_data, metadata, following_table, 
                    meta_period=(pd.datetime(2019, 2, 14), pd.datetime(2019, 3, 15)), 
                    read_period=(20190214, 20190301),
                    series_count=7):
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)
    
    # meta 전처리
    new_meta = meta_preprocessing(metadata, meta_period, use_megazine=True)
    
    # 구독한 정보를 토대로 구독하지 않은 작가들의 글만 추출할 것임. 
    following = following_table[['user_id','following_id']]
    following = following.drop_duplicates(subset=['user_id','following_id'])
    following['following'] = 1
    
    # 구독하지 않은 작가의 읽은 정보
    series_table = pd.DataFrame()
    series_table['user_id'] = read['user_id']
    series_table['following_id'] = read['article_id'].apply(lambda x: x.split('_')[0])
    series_table = pd.merge(series_table,following,how='left',on=['user_id','following_id'])
    series_table = series_table[series_table['following'].isnull()].reset_index(drop=True)
    del series_table['following']
    
    # 아래부터는 기존과 동일 
    series_table = pd.merge(series_table, new_meta, how='left', on='following_id') # 읽은 글하고 안읽은 글이 섞여요. 
    series_table = series_table.loc[series_table['article_id']!='']
    series_table = series_table.loc[series_table['following_id']!='']
    series_table = series_table.dropna(axis=0)
    series_table.columns = ['user_id','author_id','article_id','magazine_id','diffday_from_end']
    series_table = series_table.drop_duplicates(['user_id','article_id'])

    check_reading_table = read[['user_id','article_id']] # df_table은 읽은 것만. 
    check_reading_table['readYN'] = 1
    series_table = pd.merge(series_table, check_reading_table, how='left',on=['user_id','article_id'])
    series_table['readYN'] = series_table['readYN'].fillna(0)
    
    series_table = series_table.sort_values(by='diffday_from_end') #날짜 
    series_table = series_table.drop_duplicates(['user_id','article_id'])
    
    series_table = shift_preprocessing(series_table, ['user_id','author_id','magazine_id'], series_count)
    
    # 선호도로 얼마나 작가의 다양한 글을 읽었는지로 판단.  
    how_many_each_article_read = get_how_many_read_each_article_by_eachuser(read)
    series_table = pd.merge(series_table, how_many_each_article_read, how='left',on=['user_id','author_id'])
    
    return series_table

# %%
def dont_following_weekly_series(read_data, metadata, following_table, 
                    meta_period=(pd.datetime(2017, 7, 14), pd.datetime(2019, 3, 15)), 
                    read_period=(2019027, 20190301),
                    series_count=6):
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)
    
    # get weekly article
    weekly_meta = get_weekly_metadata(metadata)
    
    # meta 전처리
    
    # 구독한 정보를 토대로 구독하지 않은 작가들의 글만 추출할 것임. 
    following = following_table[['user_id','following_id']]
    following = following.drop_duplicates(subset=['user_id','following_id'])
    following['following'] = 1
    
    # 구독하지 않은 작가의 읽은 정보
    series_table = pd.DataFrame()
    series_table['user_id'] = read['user_id']
    series_table['following_id'] = read['article_id'].apply(lambda x: x.split('_')[0])
    series_table = pd.merge(series_table,following,how='left',on=['user_id','following_id'])
    series_table = series_table[series_table['following'].isnull()].reset_index(drop=True)
    del series_table['following']
    
    # Weekly 글만 추출 
    series_table = series_table.merge(weekly_meta, on=['following_id'], how='left')
    
    # 아래부터는 기존과 동일 
    series_table = series_table.loc[series_table['article_id']!='']
    series_table = series_table.loc[series_table['following_id']!='']
    series_table = series_table.dropna(axis=0)
    
    #['user_id', 'following_id', 'magazine_id', 'article_id', 'weekly','diffday_from_end']    
    series_table.columns = ['user_id','author_id','magazine_id','article_id','weekly','diffday_from_end']
    series_table = series_table.drop_duplicates(['user_id','article_id'])

    check_reading_table = read[['user_id','article_id']] # df_table은 읽은 것만. 
    check_reading_table['readYN'] = 1
    series_table = pd.merge(series_table, check_reading_table, how='left',on=['user_id','article_id'])
    series_table['readYN'] = series_table['readYN'].fillna(0)
    
    series_table = series_table.sort_values(by='diffday_from_end') #날짜 
    series_table = series_table.drop_duplicates(['user_id','article_id'])
    
    series_table = shift_preprocessing(series_table, ['user_id','author_id','magazine_id'], series_count)
    
    # 선호도로 얼마나 작가의 다양한 글을 읽었는지로 판단.  
    how_many_each_article_read = get_how_many_read_each_article_by_eachuser(read)
    series_table = pd.merge(series_table, how_many_each_article_read, how='left',on=['user_id','author_id'])
    
    return series_table

# %%
def get_regression_best(read_data, metadata, 
                        regresssion_meta_period=(pd.datetime(2019, 2, 1), pd.datetime(2019, 3, 1)), 
                        regression_read_period=(20190201, 20190301)):
    # regression_read2
    read_regression = read_preprocessing(read_data, metadata, regression_read_period)
    read_regression = read_regression['article_id'].value_counts().reset_index()
    read_regression.columns = ['article_id', 'value_counts']
    
    # regresssion_meta2 ['following_id', 'article_id', 'diffday_from_end', 'reg_dt']
    meta_regression = meta_preprocessing(metadata, regresssion_meta_period, use_megazine=False, use_regdt=True)
    meta_regression = meta_regression[['article_id','reg_dt']]
    
    regression_best = pd.merge(read_regression, meta_regression, how='left',on='article_id')
    regression_best['diff_reg_datetime'] = pd.datetime(2019, 3, 1, 0, 0) - pd.to_datetime(regression_best['reg_dt'])
    regression_best = regression_best.dropna(axis=0)

    # 차이가 나는 날짜 계산
    regression_best['diff_reg_hr'] = 24*regression_best['diff_reg_datetime'].dt.days + pd.to_datetime(regression_best['diff_reg_datetime']).dt.hour
    regression_best['count'] = regression_best['value_counts'] / regression_best['diff_reg_hr']

    # 작가 별 평균 count 계산하기. ( count = 시간당 사람들이 글을 읽는 횟수) 
    regression_best['author_id'] = regression_best['article_id'].apply(lambda x: x.split('_')[0])
    regression_best = regression_best.groupby(['author_id'])['count'].agg({'mean'}).reset_index()
    
    return regression_best

def regression_march(read_data, metadata, following_table,
                        meta_period=(pd.datetime(2019, 3, 1), pd.datetime(2019, 3, 15)), 
                        read_period=(20190214, 20190301),
                        regresssion_meta_period=(pd.datetime(2019, 2, 1), pd.datetime(2019, 3, 1)), 
                        regression_read_period=(20190201, 20190301)):
    
    regression_best = get_regression_best(read_data, metadata, regresssion_meta_period, regression_read_period)
    
    # meta 전처리 diffday_from_end
    new_meta = meta_preprocessing(metadata, meta_period, use_megazine=False, use_regdt=True)
    new_meta = new_meta[['article_id','reg_dt']]
    new_meta['reg_dt'] = pd.to_datetime(new_meta['reg_dt'])
    new_meta['diff_reg_datetime'] = pd.datetime(2019, 3, 15, 0, 0) - new_meta['reg_dt']
    new_meta['diff_reg_hr'] = 24*new_meta['diff_reg_datetime'].dt.days + pd.to_datetime(new_meta['diff_reg_datetime']).dt.hour
    new_meta['author_id'] = new_meta['article_id'].apply(lambda x: x.split('_')[0])
    
    new_meta = pd.merge(new_meta, regression_best, how='left', on='author_id')
    new_meta['count'] = new_meta['mean'] * new_meta['diff_reg_hr']
    new_meta = new_meta[['article_id','author_id','count']]
    
    # 3월달의 user별 구독작가 정보를 토대로 한 추천결과 만들기. 
    following = following_table.copy()
    following.columns = ['user_id','author_id']
    regression_march = pd.merge(following, new_meta, how='left',on='author_id')
    
    # read 전처리
    read = read_preprocessing(read_data, metadata, read_period)
    # eda_table user별로 작가의 글을 몇번 읽었는지, return ['user_id', 'author_id', 'count']
    eda_table = get_how_many_read_by_eachuser(read) 
    
    regression_march = pd.merge(regression_march, eda_table,how='left',on=['user_id','author_id'])
    regression_march.columns = ['user_id','author_id','article_id','regression_cnt','favor_cnt']
    regression_march = regression_march.sort_values(by=['favor_cnt','regression_cnt'], ascending=[False,False])
    regression_march = regression_march.dropna(axis=0)
    
    return regression_march

# %%
def make_timebased_best(readdata, metadata, read_period=(20190221, 20190301)):
    """
    read_period의 시작은 실제보다 하루 작게
    """
    read = read_preprocessing(readdata, metadata , read_period=read_period)
    
    time_based_best = []
    base_read = sorted(read['from'].unique())[23:]
    for item in itertools.zip_longest(base_read, base_read[1:], base_read[2:]):
        try:
            if isinstance(item[1], np.int64) is False:
                raise BaseException(item[1])

            temp = read.loc[read['from'].isin(item),'article_id'].value_counts().reset_index()
            temp.columns = ['article_id','count']
            temp['dt'] = item[1]
        except BaseException as e:
            print(e)
            pass
        else:
            time_based_best.append(temp)
            
    time_based_best = pd.concat(time_based_best)
    """
    result_list = []
    for user_id in tqdm_notebook(user_id_frame['user_id'].unique()):
        from_list = sorted(read.loc[read['user_id']==user_id,'from'].unique())
        for t in from_list:
            temp = time_based_best.loc[time_based_best['dt']==t].reset_index(drop=True)
            temp['user_id'] = user_id
            temp['index'] = range(temp.shape[0])
            result_list.append(temp)
 
    frame = pd.concat(result_list)
    frame = frame.sort_values(['user_id','index','count'],ascending=[False, True, False])
    print(frame.shape)
    return frame
    """
    return time_based_best

# %%
def best_correction(readdata, metadata, read_period=(20190201, 20190301)):
    # best model
    most_read_article = read_preprocessing(readdata, metadata ,read_period=read_period) # 2/22 ~ 2/28

    # 가장 많이 읽은 article_id, 마지막 모델에 사용하기 위하여 만듬
    most_read_article = most_read_article['article_id'].value_counts().reset_index()
    most_read_article.columns = ['article_id','value_counts']

    temp = metadata.copy()
    del temp['article_id']
    temp = temp.rename(columns={'id':'article_id'})
    temp = temp[['article_id','reg_dt']]

    most_read_article = most_read_article.merge(temp, on='article_id', how='left')
    most_read_article['dt'] = (pd.datetime(2019, 3, 1, 0, 0) - pd.to_datetime(most_read_article['reg_dt'])).dt.days
    most_read_article['count'] = most_read_article['value_counts']/most_read_article['dt']
    most_read_article = most_read_article.sort_values('count',ascending=False)
    most_read_article = most_read_article[['article_id','count']]
    return most_read_article

# %% [markdown]
# ### Data Load

# %%
read_rowwise = pd.read_csv('res/read_rowwise_v2.csv')
read_rowwise['dt'] = read_rowwise['from']/100
read_rowwise['dt'] = read_rowwise['dt'].astype(int)
read_rowwise = read_rowwise.dropna()

users = pd.read_json('res/users.json', lines=True)
dev_user = pd.read_csv('res/predict/dev.users',header=None, names=['dev'])
test_user = pd.read_csv('res/predict/test.users',header=None, names=['test'])

metadata = pd.read_json('res/metadata.json', lines=True)
# 부정확 할 수 있지만 reg_ts 0으로 두는 것보다는 좋을 것 같아서 1970 이전에 쓴글의 reg_ts를 가져옴
# 물론 article_id가 글의 연재 순서가 아닐 수 있지만 magazine은 거의 연재순서와 일치하고 일반 기사도 향성이 있어서 이렇게 함
metadata = pd.read_json('res/metadata.json', lines=True)
metadata.loc[metadata['reg_ts']==0,'reg_ts'] = np.nan
metadata.sort_values(['user_id','article_id'], inplace=True)
metadata['reg_ts'].fillna(method='bfill', inplace=True)
metadata['reg_dt'] = metadata['reg_ts'].apply(lambda x : datetime.fromtimestamp(x/1000.0))
metadata['reg_dt'] = metadata['reg_dt'].dt.date

#metadata.sort_values(['user_id','article_id'], inplace=True)
#metadata['reg_ts'].fillna(method='bfill', inplace=True)
#metadata['reg_dt'] = metadata['reg_ts'].apply(lambda x : datetime.fromtimestamp(x/1000.0))

# 0301부터 했을 때는 더 나빠졌습니다. 
metadata = metadata.loc[pd.to_datetime(metadata['reg_dt']) <= pd.datetime(2019, 3, 14)]
metadata = metadata.sort_index()
metadata = metadata.reset_index(drop=True)

# %%
def chainer(s):
    return list(itertools.chain.from_iterable(s))

following_list_count = users['following_list'].map(len)
following_rowwise = pd.DataFrame({'user_id': np.repeat(users['id'], following_list_count),
                                  'keyword_list': np.repeat(users['keyword_list'], following_list_count),
                                  'following_id': chainer(users['following_list'])})

# %% [markdown]
# #### Parameter 설정

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# 현우님 모델은 크게 2가지로 나뉘는데<br>
# 1. 2/14 ~ 2/28일간에 읽은 정보를 사용한 모델
#  - weekly->series->following_favor->following_favor1->various_user->read_favor->most_read
# 2. 읽은 정보가 없는 모델
#  - weekly->series->following_favor->following_favor1->various_user->most_read
#
# 사실 둘이 같이써도 무방할 것 같다. 왜냐하면 어차피 없어서 추천을 못할거니까<br>

# %% [markdown]
# ### 추천모델에 사용될 추천 frame 생성

# %%
dev_following_df = following_rowwise.loc[following_rowwise['user_id'].isin(dev_user['dev']),['user_id','following_id']]
dev_following_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Parameter

# %%
read_check_period = (20190101, 20190301)

weekly_meta_period=(pd.datetime(2017, 7, 14, 0, 0), pd.datetime(2019, 3, 15, 0, 0))
weekly_read_period=(20190207, 20190301)
weekly_series_count = 6

series_meta_period=(pd.datetime(2019, 2, 1, 0, 0), pd.datetime(2019, 3, 15, 0, 0))
series_read_period=(20190207, 20190301)
series_series_count = 7

dont_following_series_meta_period=(pd.datetime(2019, 2, 1, 0, 0), pd.datetime(2019, 3, 15, 0, 0))
dont_following_series_read_period=(20190214, 20190301)
dont_following_series_series_count = 7

dont_following_weekly_meta_period=(pd.datetime(2017, 7, 14, 0, 0), pd.datetime(2019, 3, 15, 0, 0))
dont_following_weekly_read_period=(20190214, 20190301)
dont_following_weekly_series_count = 6

following_meta_period=(pd.datetime(2019, 2, 1, 0, 0), pd.datetime(2019, 3, 15, 0, 0))
following_read_period=(20190207, 20190301)
following_favor_cutoff=0.05

dont_following_meta_period=(pd.datetime(2019, 2, 1, 0, 0), pd.datetime(2019, 3, 15, 0, 0))
dont_following_read_period=(20190214, 20190301) # 구독을 안했기에 최신 선호도를 반영하고 싶음. 
dont_following_favor_cutoff=0.05

variable_user_model_read_period = (20190214, 20190301)

regression_model_meta_period=(pd.datetime(2019, 2, 28, 0, 0), pd.datetime(2019, 3, 15, 0, 0))
regression_model_read_period=(20190214, 20190301)
regresssion_before_meta_period=(pd.datetime(2019, 2, 1, 0, 0), pd.datetime(2019, 2, 28, 0, 0))
regression_before_read_period=(20190201, 20190301)

best_read_period = (20190222, 20190301)
best_correction_read_period = (20190207, 20190301)
time_based_best_period = (20190221, 20190301)

# %%
# brunch model
brunch_table = pd.DataFrame()
brunch_notice = ['@brunch_153','@brunch_151']
brunch_table['article_id'] = brunch_notice

# weekly model
weekly_table = weekly_magazine_series(read_rowwise, 
                                      metadata, 
                                      dev_following_df, 
                                      meta_period=weekly_meta_period, 
                                      read_period=weekly_read_period, 
                                      series_count=weekly_series_count) # clear

# series model
series_table = magazine_series(read_rowwise, 
                               metadata, 
                               dev_following_df,
                               meta_period=series_meta_period, 
                               read_period=series_read_period, 
                               series_count=series_series_count) # clear

# dont_following_magazine_series
dont_series_table = dont_following_magazine_series(read_rowwise, 
                                                   metadata, 
                                                   dev_following_df,
                                                   meta_period=dont_following_series_meta_period, 
                                                   read_period=dont_following_series_read_period, 
                                                   series_count=dont_following_series_series_count) 

# dont_following_weekly_series
dont_weekly_table = dont_following_weekly_series(read_rowwise, 
                                                 metadata, 
                                                 dev_following_df,
                                                 meta_period=dont_following_weekly_meta_period, 
                                                 read_period=dont_following_weekly_read_period, 
                                                 series_count=dont_following_weekly_series_count) 

# best model
most_read_article = read_preprocessing(read_rowwise, metadata ,read_period=best_read_period) # 2/22 ~ 2/28

# 가장 많이 읽은 article_id, 마지막 모델에 사용하기 위하여 만듬
most_read_article = most_read_article['article_id'].value_counts().reset_index()
most_read_article.columns = ['article_id','value_counts']

# 구독작가에 맞는 추천을 하기 위하여 사용
# cumcount는 그룹을 나타내주는데 가장 많이 읽은 article부터 작가의 rank를 나타냄
most_read_article['author_id'] = most_read_article['article_id'].apply(lambda x : x.split('_')[0])
most_read_article['rank'] = most_read_article.groupby(['author_id'])['author_id'].agg({'cumcount'}).reset_index(drop=True)
most_read_article_author_rank = most_read_article.copy()

# following model
following_favor_many_read = following_favor_frame(read_rowwise, 
                                                  metadata, 
                                                  dev_following_df, 
                                                  most_read_article_author_rank, 
                                                  correction_type=0,
                                                  meta_period=following_meta_period,
                                                  read_period=following_read_period,
                                                  favor_cutoff=following_favor_cutoff) # clear

# following model
following_favor_repeat_read = following_favor_frame(read_rowwise, 
                                                  metadata, 
                                                  dev_following_df, 
                                                  most_read_article_author_rank, 
                                                  correction_type=1,
                                                  meta_period=following_meta_period,
                                                  read_period=following_read_period,
                                                  favor_cutoff=following_favor_cutoff) # clear

"""
# dont_following_favor_frame
dont_following_favor_each_read = dont_following_favor_frame(read_rowwise, 
                                                  metadata, 
                                                  dev_following_df, 
                                                  most_read_article_author_rank, 
                                                  correction_type=2,
                                                  meta_period=dont_following_meta_period,
                                                  read_period=dont_following_read_period,
                                                  favor_cutoff=dont_following_favor_cutoff)
"""

# variable model
read_temp = read_preprocessing(read_rowwise, metadata , read_period=variable_user_model_read_period)
variable_user = get_how_many_read_by_variableuser_article(read_temp) # clear

# user correction model
dev_user_frame = dev_user.rename(columns={'dev':'user_id'})
read_user_correction, dontread_user_correction  = count_correlction_read_favor(read_rowwise, 
                                                                               metadata, 
                                                                               dev_user_frame,
                                                                               meta_period=following_meta_period,
                                                                               read_period=following_read_period,
                                                                               favor_cutoff=following_favor_cutoff) # clear

# regression march
regression_march_table = regression_march(read_rowwise, metadata, dev_following_df,
                                meta_period = regression_model_meta_period,
                                read_period = regression_model_read_period,
                                regresssion_meta_period = regresssion_before_meta_period,
                                regression_read_period = regression_before_read_period)

# best read
most_read_article_frame = most_read_article.copy() # clear

# read check
read_check_frame = read_preprocessing(read_rowwise, metadata ,read_period=read_check_period)

best_correction_frame = best_correction(read_rowwise, metadata, read_period=best_correction_read_period)
"""
# time based best
timebased_best_user = read_preprocessing(read_rowwise, metadata , read_period=best_read_period)
timebased_best_user = timebased_best_user.loc[timebased_best_user['user_id'].isin(dev_user['dev'].values)].reset_index(drop=True)
timebased_best_time = make_timebased_best(read_rowwise, metadata, read_period=time_based_best_period)
"""
# Out:
# read
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# weekly_meta
# magazine_table
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# read_user (7815123, 4)
# dontread_user (128, 4)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:33: FutureWarning: Passing timedelta64-dtype data is deprecated, will raise a TypeError in a future version
# /anaconda3/envs/myKaggle/lib/python3.6/site-packages/ipykernel_launcher.py:101: FutureWarning: Passing timedelta64-dtype data is deprecated, will raise a TypeError in a future version
# "\n# time based best\ntimebased_best_user = read_preprocessing(read_rowwise, metadata , read_period=best_read_period)\ntimebased_best_user = timebased_best_user.loc[timebased_best_user['user_id'].isin(dev_user['dev'].values)].reset_index(drop=True)\ntimebased_best_time = make_timebased_best(read_rowwise, metadata, read_period=time_based_best_period)\n"

# %% [markdown]
# ### Modeling

# %%
weekly_model = CutoffRecommend(weekly_table, cutoff_recommend_count=10, userbased_model=True, continous_read=True)
series_model = CutoffRecommend(series_table, cutoff_recommend_count=10, userbased_model=True, continous_read=True)
dont_series_model = CutoffRecommend(dont_series_table, cutoff_recommend_count=10, userbased_model=True, continous_read=True)
dont_weekly_model = CutoffRecommend(dont_weekly_table, cutoff_recommend_count=10, userbased_model=True, continous_read=True)
following_favor_many_read_model = CutoffRecommend(following_favor_many_read, cutoff_recommend_count=26, userbased_model=True)
following_favor_repeat_read_model = CutoffRecommend(following_favor_repeat_read, cutoff_recommend_count=26, userbased_model=True)
# dont_following_favor_each_read_model = CutoffRecommend(dont_following_favor_each_read, cutoff_recommend_count=10, userbased_model=True)
variable_user_model = CutoffRecommend(variable_user, cutoff_recommend_count=4, userbased_model=False)
brunch_model = CutoffRecommend(brunch_table, cutoff_recommend_count=2, userbased_model=False)
regression_user_model = CutoffRecommend(regression_march_table, cutoff_recommend_count=21, userbased_model=True)
correction_favor_model = CutoffRecommend(read_user_correction, cutoff_recommend_count=30, userbased_model=True)
# timebased_best_model = TimebasedRecommend(timebased_best_user, timebased_best_time, cutoff_recommend_count=-1)
most_read_article_model = RandomBestRecommend(best_correction_frame, cutoff_recommend_count=-1)

# %%
brunch_recommend_read = BrunchRecommend(read_user_correction['user_id'].unique(), read_check_frame)
read_model_list = [ weekly_model, series_model, dont_series_model, dont_weekly_model, following_favor_many_read_model, 
                   following_favor_repeat_read_model, variable_user_model, brunch_model, regression_user_model, 
                   correction_favor_model, most_read_article_model]
brunch_recommend_read.recommend(read_model_list)
# Out:
# HBox(children=(IntProgress(value=0, max=2872), HTML(value='')))
# RandomBestRecommend
# 62
# RandomBestRecommend
# 18
# RandomBestRecommend
# 58
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 55
# RandomBestRecommend
# 45
# RandomBestRecommend
# 38
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 61
# RandomBestRecommend
# 45
# RandomBestRecommend
# 0
# RandomBestRecommend
# 50
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 6
# RandomBestRecommend
# 47
# RandomBestRecommend
# 43
# RandomBestRecommend
# 81
# RandomBestRecommend
# 64
# RandomBestRecommend
# 55
# RandomBestRecommend
# 58
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 34
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 56
# RandomBestRecommend
# 65
# RandomBestRecommend
# 47
# RandomBestRecommend
# 26
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 48
# RandomBestRecommend
# 70
# RandomBestRecommend
# 25
# RandomBestRecommend
# 62
# RandomBestRecommend
# 10
# RandomBestRecommend
# 0
# RandomBestRecommend
# 43
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 45
# RandomBestRecommend
# 59
# RandomBestRecommend
# 63
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 64
# RandomBestRecommend
# 49
# RandomBestRecommend
# 28
# RandomBestRecommend
# 16
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 64
# RandomBestRecommend
# 34
# RandomBestRecommend
# 51
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 31
# RandomBestRecommend
# 61
# RandomBestRecommend
# 61
# RandomBestRecommend
# 37
# RandomBestRecommend
# 38
# RandomBestRecommend
# 1
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 39
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 18
# RandomBestRecommend
# 57
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 51
# RandomBestRecommend
# 64
# RandomBestRecommend
# 91
# RandomBestRecommend
# 63
# RandomBestRecommend
# 30
# RandomBestRecommend
# 38
# RandomBestRecommend
# 53
# RandomBestRecommend
# 56
# RandomBestRecommend
# 28
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 52
# RandomBestRecommend
# 33
# RandomBestRecommend
# 56
# RandomBestRecommend
# 47
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 50
# RandomBestRecommend
# 65
# RandomBestRecommend
# 53
# RandomBestRecommend
# 6
# RandomBestRecommend
# 47
# RandomBestRecommend
# 56
# RandomBestRecommend
# 62
# RandomBestRecommend
# 28
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 44
# RandomBestRecommend
# 65
# RandomBestRecommend
# 53
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 46
# RandomBestRecommend
# 63
# RandomBestRecommend
# 63
# RandomBestRecommend
# 36
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 55
# RandomBestRecommend
# 64
# RandomBestRecommend
# 44
# RandomBestRecommend
# 47
# RandomBestRecommend
# 47
# RandomBestRecommend
# 13
# RandomBestRecommend
# 65
# RandomBestRecommend
# 2
# RandomBestRecommend
# 62
# RandomBestRecommend
# 11
# RandomBestRecommend
# 64
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 56
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 3
# RandomBestRecommend
# 14
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 60
# RandomBestRecommend
# 7
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 70
# RandomBestRecommend
# 8
# RandomBestRecommend
# 56
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 0
# RandomBestRecommend
# 47
# RandomBestRecommend
# 33
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 31
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 47
# RandomBestRecommend
# 69
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 43
# RandomBestRecommend
# 60
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 52
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 72
# RandomBestRecommend
# 65
# RandomBestRecommend
# 50
# RandomBestRecommend
# 65
# RandomBestRecommend
# 41
# RandomBestRecommend
# 37
# RandomBestRecommend
# 61
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 63
# RandomBestRecommend
# 59
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 5
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 46
# RandomBestRecommend
# 19
# RandomBestRecommend
# 65
# RandomBestRecommend
# 17
# RandomBestRecommend
# 21
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 80
# RandomBestRecommend
# 27
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 22
# RandomBestRecommend
# 65
# RandomBestRecommend
# 24
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 32
# RandomBestRecommend
# 39
# RandomBestRecommend
# 41
# RandomBestRecommend
# 0
# RandomBestRecommend
# 46
# RandomBestRecommend
# 64
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 7
# RandomBestRecommend
# 65
# RandomBestRecommend
# 50
# RandomBestRecommend
# 50
# RandomBestRecommend
# 65
# RandomBestRecommend
# 6
# RandomBestRecommend
# 41
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 45
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 47
# RandomBestRecommend
# 53
# RandomBestRecommend
# 58
# RandomBestRecommend
# 59
# RandomBestRecommend
# 58
# RandomBestRecommend
# 7
# RandomBestRecommend
# 65
# RandomBestRecommend
# 15
# RandomBestRecommend
# 46
# RandomBestRecommend
# 5
# RandomBestRecommend
# 35
# RandomBestRecommend
# 0
# RandomBestRecommend
# 35
# RandomBestRecommend
# 65
# RandomBestRecommend
# 20
# RandomBestRecommend
# 61
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 54
# RandomBestRecommend
# 19
# RandomBestRecommend
# 56
# RandomBestRecommend
# 14
# RandomBestRecommend
# 2
# RandomBestRecommend
# 62
# RandomBestRecommend
# 60
# RandomBestRecommend
# 44
# RandomBestRecommend
# 88
# RandomBestRecommend
# 64
# RandomBestRecommend
# 56
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 57
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 19
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 46
# RandomBestRecommend
# 44
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 62
# RandomBestRecommend
# 42
# RandomBestRecommend
# 61
# RandomBestRecommend
# 58
# RandomBestRecommend
# 2
# RandomBestRecommend
# 64
# RandomBestRecommend
# 60
# RandomBestRecommend
# 61
# RandomBestRecommend
# 43
# RandomBestRecommend
# 36
# RandomBestRecommend
# 48
# RandomBestRecommend
# 46
# RandomBestRecommend
# 51
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 49
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 86
# RandomBestRecommend
# 64
# RandomBestRecommend
# 9
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 19
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 37
# RandomBestRecommend
# 57
# RandomBestRecommend
# 0
# RandomBestRecommend
# 50
# RandomBestRecommend
# 44
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 46
# RandomBestRecommend
# 0
# RandomBestRecommend
# 34
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 58
# RandomBestRecommend
# 64
# RandomBestRecommend
# 58
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 48
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 43
# RandomBestRecommend
# 44
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 28
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 57
# RandomBestRecommend
# 2
# RandomBestRecommend
# 65
# RandomBestRecommend
# 40
# RandomBestRecommend
# 62
# RandomBestRecommend
# 9
# RandomBestRecommend
# 0
# RandomBestRecommend
# 43
# RandomBestRecommend
# 76
# RandomBestRecommend
# 21
# RandomBestRecommend
# 39
# RandomBestRecommend
# 61
# RandomBestRecommend
# 45
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 56
# RandomBestRecommend
# 39
# RandomBestRecommend
# 57
# RandomBestRecommend
# 39
# RandomBestRecommend
# 61
# RandomBestRecommend
# 43
# RandomBestRecommend
# 54
# RandomBestRecommend
# 55
# RandomBestRecommend
# 32
# RandomBestRecommend
# 63
# RandomBestRecommend
# 16
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 63
# RandomBestRecommend
# 42
# RandomBestRecommend
# 35
# RandomBestRecommend
# 0
# RandomBestRecommend
# 44
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 15
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 54
# RandomBestRecommend
# 16
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 43
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 58
# RandomBestRecommend
# 23
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 36
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 18
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 29
# RandomBestRecommend
# 50
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 56
# RandomBestRecommend
# 35
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 62
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 62
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 40
# RandomBestRecommend
# 14
# RandomBestRecommend
# 65
# RandomBestRecommend
# 44
# RandomBestRecommend
# 51
# RandomBestRecommend
# 63
# RandomBestRecommend
# 61
# RandomBestRecommend
# 35
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 60
# RandomBestRecommend
# 46
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 56
# RandomBestRecommend
# 56
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 32
# RandomBestRecommend
# 63
# RandomBestRecommend
# 48
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 23
# RandomBestRecommend
# 32
# RandomBestRecommend
# 64
# RandomBestRecommend
# 41
# RandomBestRecommend
# 8
# RandomBestRecommend
# 48
# RandomBestRecommend
# 44
# RandomBestRecommend
# 62
# RandomBestRecommend
# 64
# RandomBestRecommend
# 37
# RandomBestRecommend
# 49
# RandomBestRecommend
# 50
# RandomBestRecommend
# 33
# RandomBestRecommend
# 49
# RandomBestRecommend
# 0
# RandomBestRecommend
# 51
# RandomBestRecommend
# 45
# RandomBestRecommend
# 65
# RandomBestRecommend
# 37
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 43
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 62
# RandomBestRecommend
# 92
# RandomBestRecommend
# 62
# RandomBestRecommend
# 38
# RandomBestRecommend
# 56
# RandomBestRecommend
# 0
# RandomBestRecommend
# 28
# RandomBestRecommend
# 65
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 54
# RandomBestRecommend
# 14
# RandomBestRecommend
# 59
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 61
# RandomBestRecommend
# 58
# RandomBestRecommend
# 18
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 5
# RandomBestRecommend
# 0
# RandomBestRecommend
# 84
# RandomBestRecommend
# 27
# RandomBestRecommend
# 61
# RandomBestRecommend
# 33
# RandomBestRecommend
# 0
# RandomBestRecommend
# 47
# RandomBestRecommend
# 64
# RandomBestRecommend
# 35
# RandomBestRecommend
# 10
# RandomBestRecommend
# 46
# RandomBestRecommend
# 64
# RandomBestRecommend
# 50
# RandomBestRecommend
# 0
# RandomBestRecommend
# 44
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 94
# RandomBestRecommend
# 5
# RandomBestRecommend
# 24
# RandomBestRecommend
# 60
# RandomBestRecommend
# 55
# RandomBestRecommend
# 64
# RandomBestRecommend
# 56
# RandomBestRecommend
# 46
# RandomBestRecommend
# 39
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 44
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 55
# RandomBestRecommend
# 43
# RandomBestRecommend
# 35
# RandomBestRecommend
# 11
# RandomBestRecommend
# 65
# RandomBestRecommend
# 26
# RandomBestRecommend
# 64
# RandomBestRecommend
# 62
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 51
# RandomBestRecommend
# 41
# RandomBestRecommend
# 29
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 19
# RandomBestRecommend
# 50
# RandomBestRecommend
# 7
# RandomBestRecommend
# 59
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 35
# RandomBestRecommend
# 62
# RandomBestRecommend
# 64
# RandomBestRecommend
# 27
# RandomBestRecommend
# 59
# RandomBestRecommend
# 54
# RandomBestRecommend
# 34
# RandomBestRecommend
# 49
# RandomBestRecommend
# 0
# RandomBestRecommend
# 82
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 43
# RandomBestRecommend
# 2
# RandomBestRecommend
# 63
# RandomBestRecommend
# 47
# RandomBestRecommend
# 53
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 0
# RandomBestRecommend
# 51
# RandomBestRecommend
# 16
# RandomBestRecommend
# 52
# RandomBestRecommend
# 59
# RandomBestRecommend
# 46
# RandomBestRecommend
# 73
# RandomBestRecommend
# 65
# RandomBestRecommend
# 17
# RandomBestRecommend
# 56
# RandomBestRecommend
# 59
# RandomBestRecommend
# 61
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 6
# RandomBestRecommend
# 62
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 46
# RandomBestRecommend
# 0
# RandomBestRecommend
# 44
# RandomBestRecommend
# 45
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 56
# RandomBestRecommend
# 63
# RandomBestRecommend
# 42
# RandomBestRecommend
# 58
# RandomBestRecommend
# 11
# RandomBestRecommend
# 51
# RandomBestRecommend
# 2
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 37
# RandomBestRecommend
# 53
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 30
# RandomBestRecommend
# 65
# RandomBestRecommend
# 54
# RandomBestRecommend
# 39
# RandomBestRecommend
# 60
# RandomBestRecommend
# 27
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 26
# RandomBestRecommend
# 26
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 55
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 15
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 13
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 40
# RandomBestRecommend
# 62
# RandomBestRecommend
# 36
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 61
# RandomBestRecommend
# 60
# RandomBestRecommend
# 39
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 65
# RandomBestRecommend
# 54
# RandomBestRecommend
# 0
# RandomBestRecommend
# 45
# RandomBestRecommend
# 61
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 27
# RandomBestRecommend
# 6
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 32
# RandomBestRecommend
# 76
# RandomBestRecommend
# 55
# RandomBestRecommend
# 56
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 25
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 54
# RandomBestRecommend
# 39
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 64
# RandomBestRecommend
# 21
# RandomBestRecommend
# 64
# RandomBestRecommend
# 34
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 62
# RandomBestRecommend
# 62
# RandomBestRecommend
# 28
# RandomBestRecommend
# 65
# RandomBestRecommend
# 22
# RandomBestRecommend
# 52
# RandomBestRecommend
# 65
# RandomBestRecommend
# 33
# RandomBestRecommend
# 51
# RandomBestRecommend
# 24
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 36
# RandomBestRecommend
# 48
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 26
# RandomBestRecommend
# 53
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 51
# RandomBestRecommend
# 34
# RandomBestRecommend
# 58
# RandomBestRecommend
# 56
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 32
# RandomBestRecommend
# 61
# RandomBestRecommend
# 86
# RandomBestRecommend
# 54
# RandomBestRecommend
# 48
# RandomBestRecommend
# 47
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 44
# RandomBestRecommend
# 27
# RandomBestRecommend
# 37
# RandomBestRecommend
# 46
# RandomBestRecommend
# 65
# RandomBestRecommend
# 33
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 51
# RandomBestRecommend
# 52
# RandomBestRecommend
# 31
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 41
# RandomBestRecommend
# 0
# RandomBestRecommend
# 44
# RandomBestRecommend
# 55
# RandomBestRecommend
# 45
# RandomBestRecommend
# 53
# RandomBestRecommend
# 43
# RandomBestRecommend
# 63
# RandomBestRecommend
# 51
# RandomBestRecommend
# 21
# RandomBestRecommend
# 64
# RandomBestRecommend
# 52
# RandomBestRecommend
# 55
# RandomBestRecommend
# 38
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 52
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 17
# RandomBestRecommend
# 3
# RandomBestRecommend
# 65
# RandomBestRecommend
# 33
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 27
# RandomBestRecommend
# 65
# RandomBestRecommend
# 92
# RandomBestRecommend
# 35
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 55
# RandomBestRecommend
# 63
# RandomBestRecommend
# 7
# RandomBestRecommend
# 62
# RandomBestRecommend
# 63
# RandomBestRecommend
# 17
# RandomBestRecommend
# 57
# RandomBestRecommend
# 55
# RandomBestRecommend
# 0
# RandomBestRecommend
# 54
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 22
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 71
# RandomBestRecommend
# 65
# RandomBestRecommend
# 52
# RandomBestRecommend
# 3
# RandomBestRecommend
# 54
# RandomBestRecommend
# 32
# RandomBestRecommend
# 23
# RandomBestRecommend
# 62
# RandomBestRecommend
# 50
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 40
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 49
# RandomBestRecommend
# 55
# RandomBestRecommend
# 64
# RandomBestRecommend
# 42
# RandomBestRecommend
# 8
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 14
# RandomBestRecommend
# 48
# RandomBestRecommend
# 63
# RandomBestRecommend
# 31
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 52
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 1
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 49
# RandomBestRecommend
# 26
# RandomBestRecommend
# 26
# RandomBestRecommend
# 47
# RandomBestRecommend
# 0
# RandomBestRecommend
# 22
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 42
# RandomBestRecommend
# 23
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 30
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 62
# RandomBestRecommend
# 60
# RandomBestRecommend
# 57
# RandomBestRecommend
# 18
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 30
# RandomBestRecommend
# 51
# RandomBestRecommend
# 38
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 19
# RandomBestRecommend
# 65
# RandomBestRecommend
# 45
# RandomBestRecommend
# 0
# RandomBestRecommend
# 37
# RandomBestRecommend
# 6
# RandomBestRecommend
# 62
# RandomBestRecommend
# 18
# RandomBestRecommend
# 44
# RandomBestRecommend
# 24
# RandomBestRecommend
# 61
# RandomBestRecommend
# 53
# RandomBestRecommend
# 60
# RandomBestRecommend
# 31
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 66
# RandomBestRecommend
# 63
# RandomBestRecommend
# 41
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 32
# RandomBestRecommend
# 80
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 63
# RandomBestRecommend
# 87
# RandomBestRecommend
# 64
# RandomBestRecommend
# 29
# RandomBestRecommend
# 47
# RandomBestRecommend
# 59
# RandomBestRecommend
# 61
# RandomBestRecommend
# 60
# RandomBestRecommend
# 64
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 34
# RandomBestRecommend
# 47
# RandomBestRecommend
# 59
# RandomBestRecommend
# 17
# RandomBestRecommend
# 51
# RandomBestRecommend
# 26
# RandomBestRecommend
# 23
# RandomBestRecommend
# 7
# RandomBestRecommend
# 31
# RandomBestRecommend
# 51
# RandomBestRecommend
# 45
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 25
# RandomBestRecommend
# 49
# RandomBestRecommend
# 52
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 30
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 15
# RandomBestRecommend
# 56
# RandomBestRecommend
# 89
# RandomBestRecommend
# 65
# RandomBestRecommend
# 48
# RandomBestRecommend
# 65
# RandomBestRecommend
# 40
# RandomBestRecommend
# 56
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 28
# RandomBestRecommend
# 64
# RandomBestRecommend
# 27
# RandomBestRecommend
# 17
# RandomBestRecommend
# 65
# RandomBestRecommend
# 44
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 47
# RandomBestRecommend
# 64
# RandomBestRecommend
# 62
# RandomBestRecommend
# 47
# RandomBestRecommend
# 47
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 60
# RandomBestRecommend
# 64
# RandomBestRecommend
# 35
# RandomBestRecommend
# 39
# RandomBestRecommend
# 65
# RandomBestRecommend
# 51
# RandomBestRecommend
# 65
# RandomBestRecommend
# 5
# RandomBestRecommend
# 58
# RandomBestRecommend
# 59
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 52
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 46
# RandomBestRecommend
# 55
# RandomBestRecommend
# 14
# RandomBestRecommend
# 54
# RandomBestRecommend
# 77
# RandomBestRecommend
# 50
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 11
# RandomBestRecommend
# 59
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 44
# RandomBestRecommend
# 57
# RandomBestRecommend
# 38
# RandomBestRecommend
# 32
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 35
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 11
# RandomBestRecommend
# 51
# RandomBestRecommend
# 38
# RandomBestRecommend
# 62
# RandomBestRecommend
# 45
# RandomBestRecommend
# 49
# RandomBestRecommend
# 61
# RandomBestRecommend
# 61
# RandomBestRecommend
# 40
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 64
# RandomBestRecommend
# 34
# RandomBestRecommend
# 9
# RandomBestRecommend
# 45
# RandomBestRecommend
# 63
# RandomBestRecommend
# 59
# RandomBestRecommend
# 32
# RandomBestRecommend
# 43
# RandomBestRecommend
# 33
# RandomBestRecommend
# 46
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 46
# RandomBestRecommend
# 64
# RandomBestRecommend
# 56
# RandomBestRecommend
# 54
# RandomBestRecommend
# 49
# RandomBestRecommend
# 92
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 22
# RandomBestRecommend
# 35
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 8
# RandomBestRecommend
# 0
# RandomBestRecommend
# 1
# RandomBestRecommend
# 15
# RandomBestRecommend
# 63
# RandomBestRecommend
# 60
# RandomBestRecommend
# 46
# RandomBestRecommend
# 62
# RandomBestRecommend
# 2
# RandomBestRecommend
# 57
# RandomBestRecommend
# 59
# RandomBestRecommend
# 42
# RandomBestRecommend
# 10
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 59
# RandomBestRecommend
# 50
# RandomBestRecommend
# 18
# RandomBestRecommend
# 0
# RandomBestRecommend
# 21
# RandomBestRecommend
# 15
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 59
# RandomBestRecommend
# 51
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 46
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 39
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 46
# RandomBestRecommend
# 23
# RandomBestRecommend
# 65
# RandomBestRecommend
# 35
# RandomBestRecommend
# 61
# RandomBestRecommend
# 12
# RandomBestRecommend
# 64
# RandomBestRecommend
# 85
# RandomBestRecommend
# 35
# RandomBestRecommend
# 49
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 61
# RandomBestRecommend
# 12
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 55
# RandomBestRecommend
# 17
# RandomBestRecommend
# 24
# RandomBestRecommend
# 49
# RandomBestRecommend
# 59
# RandomBestRecommend
# 57
# RandomBestRecommend
# 42
# RandomBestRecommend
# 24
# RandomBestRecommend
# 31
# RandomBestRecommend
# 56
# RandomBestRecommend
# 57
# RandomBestRecommend
# 64
# RandomBestRecommend
# 23
# RandomBestRecommend
# 0
# RandomBestRecommend
# 50
# RandomBestRecommend
# 62
# RandomBestRecommend
# 84
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 27
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 45
# RandomBestRecommend
# 58
# RandomBestRecommend
# 70
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 83
# RandomBestRecommend
# 65
# RandomBestRecommend
# 52
# RandomBestRecommend
# 5
# RandomBestRecommend
# 40
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 36
# RandomBestRecommend
# 64
# RandomBestRecommend
# 52
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 43
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 35
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 49
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 59
# RandomBestRecommend
# 54
# RandomBestRecommend
# 16
# RandomBestRecommend
# 65
# RandomBestRecommend
# 51
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 12
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 15
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 15
# RandomBestRecommend
# 45
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 58
# RandomBestRecommend
# 55
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 12
# RandomBestRecommend
# 60
# RandomBestRecommend
# 13
# RandomBestRecommend
# 43
# RandomBestRecommend
# 42
# RandomBestRecommend
# 49
# RandomBestRecommend
# 46
# RandomBestRecommend
# 48
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 54
# RandomBestRecommend
# 0
# RandomBestRecommend
# 45
# RandomBestRecommend
# 53
# RandomBestRecommend
# 54
# RandomBestRecommend
# 60
# RandomBestRecommend
# 57
# RandomBestRecommend
# 46
# RandomBestRecommend
# 82
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 41
# RandomBestRecommend
# 50
# RandomBestRecommend
# 61
# RandomBestRecommend
# 13
# RandomBestRecommend
# 45
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 31
# RandomBestRecommend
# 52
# RandomBestRecommend
# 60
# RandomBestRecommend
# 58
# RandomBestRecommend
# 0
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 36
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 43
# RandomBestRecommend
# 3
# RandomBestRecommend
# 64
# RandomBestRecommend
# 50
# RandomBestRecommend
# 61
# RandomBestRecommend
# 62
# RandomBestRecommend
# 48
# RandomBestRecommend
# 53
# RandomBestRecommend
# 63
# RandomBestRecommend
# 45
# RandomBestRecommend
# 60
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 40
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 48
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 23
# RandomBestRecommend
# 49
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 23
# RandomBestRecommend
# 26
# RandomBestRecommend
# 46
# RandomBestRecommend
# 65
# RandomBestRecommend
# 52
# RandomBestRecommend
# 46
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 45
# RandomBestRecommend
# 54
# RandomBestRecommend
# 19
# RandomBestRecommend
# 32
# RandomBestRecommend
# 45
# RandomBestRecommend
# 16
# RandomBestRecommend
# 51
# RandomBestRecommend
# 65
# RandomBestRecommend
# 46
# RandomBestRecommend
# 53
# RandomBestRecommend
# 51
# RandomBestRecommend
# 4
# RandomBestRecommend
# 43
# RandomBestRecommend
# 51
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 21
# RandomBestRecommend
# 0
# RandomBestRecommend
# 49
# RandomBestRecommend
# 55
# RandomBestRecommend
# 64
# RandomBestRecommend
# 35
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 44
# RandomBestRecommend
# 0
# RandomBestRecommend
# 8
# RandomBestRecommend
# 65
# RandomBestRecommend
# 53
# RandomBestRecommend
# 58
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 16
# RandomBestRecommend
# 0
# RandomBestRecommend
# 29
# RandomBestRecommend
# 51
# RandomBestRecommend
# 52
# RandomBestRecommend
# 65
# RandomBestRecommend
# 33
# RandomBestRecommend
# 65
# RandomBestRecommend
# 37
# RandomBestRecommend
# 40
# RandomBestRecommend
# 32
# RandomBestRecommend
# 50
# RandomBestRecommend
# 62
# RandomBestRecommend
# 29
# RandomBestRecommend
# 1
# RandomBestRecommend
# 43
# RandomBestRecommend
# 25
# RandomBestRecommend
# 65
# RandomBestRecommend
# 20
# RandomBestRecommend
# 50
# RandomBestRecommend
# 63
# RandomBestRecommend
# 57
# RandomBestRecommend
# 64
# RandomBestRecommend
# 38
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 49
# RandomBestRecommend
# 53
# RandomBestRecommend
# 38
# RandomBestRecommend
# 51
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 23
# RandomBestRecommend
# 65
# RandomBestRecommend
# 23
# RandomBestRecommend
# 40
# RandomBestRecommend
# 57
# RandomBestRecommend
# 59
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 57
# RandomBestRecommend
# 0
# RandomBestRecommend
# 53
# RandomBestRecommend
# 4
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 25
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 53
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 40
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 61
# RandomBestRecommend
# 29
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 51
# RandomBestRecommend
# 44
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 45
# RandomBestRecommend
# 33
# RandomBestRecommend
# 13
# RandomBestRecommend
# 63
# RandomBestRecommend
# 58
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 24
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 13
# RandomBestRecommend
# 29
# RandomBestRecommend
# 0
# RandomBestRecommend
# 52
# RandomBestRecommend
# 31
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 74
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 34
# RandomBestRecommend
# 56
# RandomBestRecommend
# 63
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 15
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 23
# RandomBestRecommend
# 62
# RandomBestRecommend
# 34
# RandomBestRecommend
# 40
# RandomBestRecommend
# 0
# RandomBestRecommend
# 45
# RandomBestRecommend
# 50
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 46
# RandomBestRecommend
# 64
# RandomBestRecommend
# 50
# RandomBestRecommend
# 15
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 20
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 61
# RandomBestRecommend
# 59
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 45
# RandomBestRecommend
# 65
# RandomBestRecommend
# 16
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 3
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 42
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 47
# RandomBestRecommend
# 50
# RandomBestRecommend
# 45
# RandomBestRecommend
# 63
# RandomBestRecommend
# 48
# RandomBestRecommend
# 64
# RandomBestRecommend
# 53
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 45
# RandomBestRecommend
# 56
# RandomBestRecommend
# 46
# RandomBestRecommend
# 51
# RandomBestRecommend
# 43
# RandomBestRecommend
# 55
# RandomBestRecommend
# 59
# RandomBestRecommend
# 63
# RandomBestRecommend
# 55
# RandomBestRecommend
# 0
# RandomBestRecommend
# 29
# RandomBestRecommend
# 1
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 63
# RandomBestRecommend
# 63
# RandomBestRecommend
# 55
# RandomBestRecommend
# 30
# RandomBestRecommend
# 0
# RandomBestRecommend
# 13
# RandomBestRecommend
# 52
# RandomBestRecommend
# 42
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 45
# RandomBestRecommend
# 52
# RandomBestRecommend
# 62
# RandomBestRecommend
# 13
# RandomBestRecommend
# 63
# RandomBestRecommend
# 62
# RandomBestRecommend
# 52
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 17
# RandomBestRecommend
# 34
# RandomBestRecommend
# 64
# RandomBestRecommend
# 26
# RandomBestRecommend
# 3
# RandomBestRecommend
# 45
# RandomBestRecommend
# 1
# RandomBestRecommend
# 54
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 35
# RandomBestRecommend
# 57
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 9
# RandomBestRecommend
# 18
# RandomBestRecommend
# 46
# RandomBestRecommend
# 65
# RandomBestRecommend
# 36
# RandomBestRecommend
# 12
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 62
# RandomBestRecommend
# 46
# RandomBestRecommend
# 19
# RandomBestRecommend
# 44
# RandomBestRecommend
# 64
# RandomBestRecommend
# 55
# RandomBestRecommend
# 92
# RandomBestRecommend
# 65
# RandomBestRecommend
# 33
# RandomBestRecommend
# 59
# RandomBestRecommend
# 44
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 24
# RandomBestRecommend
# 88
# RandomBestRecommend
# 7
# RandomBestRecommend
# 17
# RandomBestRecommend
# 34
# RandomBestRecommend
# 56
# RandomBestRecommend
# 8
# RandomBestRecommend
# 26
# RandomBestRecommend
# 13
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 44
# RandomBestRecommend
# 53
# RandomBestRecommend
# 12
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 40
# RandomBestRecommend
# 51
# RandomBestRecommend
# 3
# RandomBestRecommend
# 65
# RandomBestRecommend
# 5
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 76
# RandomBestRecommend
# 40
# RandomBestRecommend
# 65
# RandomBestRecommend
# 54
# RandomBestRecommend
# 64
# RandomBestRecommend
# 48
# RandomBestRecommend
# 56
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 40
# RandomBestRecommend
# 58
# RandomBestRecommend
# 49
# RandomBestRecommend
# 73
# RandomBestRecommend
# 58
# RandomBestRecommend
# 0
# RandomBestRecommend
# 40
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 47
# RandomBestRecommend
# 48
# RandomBestRecommend
# 62
# RandomBestRecommend
# 49
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 45
# RandomBestRecommend
# 44
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 6
# RandomBestRecommend
# 60
# RandomBestRecommend
# 56
# RandomBestRecommend
# 58
# RandomBestRecommend
# 37
# RandomBestRecommend
# 66
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 41
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 48
# RandomBestRecommend
# 65
# RandomBestRecommend
# 40
# RandomBestRecommend
# 10
# RandomBestRecommend
# 44
# RandomBestRecommend
# 61
# RandomBestRecommend
# 47
# RandomBestRecommend
# 51
# RandomBestRecommend
# 65
# RandomBestRecommend
# 43
# RandomBestRecommend
# 59
# RandomBestRecommend
# 64
# RandomBestRecommend
# 53
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 62
# RandomBestRecommend
# 64
# RandomBestRecommend
# 38
# RandomBestRecommend
# 65
# RandomBestRecommend
# 50
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 42
# RandomBestRecommend
# 30
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 82
# RandomBestRecommend
# 0
# RandomBestRecommend
# 45
# RandomBestRecommend
# 31
# RandomBestRecommend
# 60
# RandomBestRecommend
# 63
# RandomBestRecommend
# 63
# RandomBestRecommend
# 17
# RandomBestRecommend
# 63
# RandomBestRecommend
# 53
# RandomBestRecommend
# 65
# RandomBestRecommend
# 12
# RandomBestRecommend
# 36
# RandomBestRecommend
# 44
# RandomBestRecommend
# 0
# RandomBestRecommend
# 15
# RandomBestRecommend
# 22
# RandomBestRecommend
# 55
# RandomBestRecommend
# 62
# RandomBestRecommend
# 40
# RandomBestRecommend
# 0
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 18
# RandomBestRecommend
# 53
# RandomBestRecommend
# 58
# RandomBestRecommend
# 64
# RandomBestRecommend
# 29
# RandomBestRecommend
# 53
# RandomBestRecommend
# 89
# RandomBestRecommend
# 25
# RandomBestRecommend
# 50
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 49
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 60
# RandomBestRecommend
# 48
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 33
# RandomBestRecommend
# 64
# RandomBestRecommend
# 80
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 48
# RandomBestRecommend
# 62
# RandomBestRecommend
# 42
# RandomBestRecommend
# 46
# RandomBestRecommend
# 51
# RandomBestRecommend
# 46
# RandomBestRecommend
# 0
# RandomBestRecommend
# 39
# RandomBestRecommend
# 25
# RandomBestRecommend
# 62
# RandomBestRecommend
# 60
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 54
# RandomBestRecommend
# 62
# RandomBestRecommend
# 44
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 45
# RandomBestRecommend
# 90
# RandomBestRecommend
# 51
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 34
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 25
# RandomBestRecommend
# 25
# RandomBestRecommend
# 57
# RandomBestRecommend
# 41
# RandomBestRecommend
# 37
# RandomBestRecommend
# 16
# RandomBestRecommend
# 58
# RandomBestRecommend
# 62
# RandomBestRecommend
# 51
# RandomBestRecommend
# 61
# RandomBestRecommend
# 20
# RandomBestRecommend
# 0
# RandomBestRecommend
# 9
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 37
# RandomBestRecommend
# 52
# RandomBestRecommend
# 40
# RandomBestRecommend
# 89
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 0
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 38
# RandomBestRecommend
# 47
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 9
# RandomBestRecommend
# 43
# RandomBestRecommend
# 63
# RandomBestRecommend
# 12
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 5
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 31
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 9
# RandomBestRecommend
# 60
# RandomBestRecommend
# 5
# RandomBestRecommend
# 63
# RandomBestRecommend
# 23
# RandomBestRecommend
# 65
# RandomBestRecommend
# 50
# RandomBestRecommend
# 60
# RandomBestRecommend
# 61
# RandomBestRecommend
# 79
# RandomBestRecommend
# 0
# RandomBestRecommend
# 66
# RandomBestRecommend
# 64
# RandomBestRecommend
# 58
# RandomBestRecommend
# 47
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 42
# RandomBestRecommend
# 17
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 53
# RandomBestRecommend
# 49
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 45
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 50
# RandomBestRecommend
# 54
# RandomBestRecommend
# 18
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 52
# RandomBestRecommend
# 65
# RandomBestRecommend
# 45
# RandomBestRecommend
# 38
# RandomBestRecommend
# 56
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 62
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 54
# RandomBestRecommend
# 45
# RandomBestRecommend
# 17
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 48
# RandomBestRecommend
# 65
# RandomBestRecommend
# 41
# RandomBestRecommend
# 62
# RandomBestRecommend
# 57
# RandomBestRecommend
# 42
# RandomBestRecommend
# 53
# RandomBestRecommend
# 5
# RandomBestRecommend
# 58
# RandomBestRecommend
# 51
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 26
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 29
# RandomBestRecommend
# 58
# RandomBestRecommend
# 27
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 52
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 6
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 50
# RandomBestRecommend
# 56
# RandomBestRecommend
# 61
# RandomBestRecommend
# 1
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 65
# RandomBestRecommend
# 34
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 60
# RandomBestRecommend
# 33
# RandomBestRecommend
# 64
# RandomBestRecommend
# 46
# RandomBestRecommend
# 43
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 10
# RandomBestRecommend
# 48
# RandomBestRecommend
# 38
# RandomBestRecommend
# 20
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 47
# RandomBestRecommend
# 65
# RandomBestRecommend
# 12
# RandomBestRecommend
# 49
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 29
# RandomBestRecommend
# 80
# RandomBestRecommend
# 60
# RandomBestRecommend
# 63
# RandomBestRecommend
# 13
# RandomBestRecommend
# 7
# RandomBestRecommend
# 51
# RandomBestRecommend
# 65
# RandomBestRecommend
# 27
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 43
# RandomBestRecommend
# 65
# RandomBestRecommend
# 32
# RandomBestRecommend
# 62
# RandomBestRecommend
# 14
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 55
# RandomBestRecommend
# 24
# RandomBestRecommend
# 64
# RandomBestRecommend
# 57
# RandomBestRecommend
# 35
# RandomBestRecommend
# 62
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 58
# RandomBestRecommend
# 64
# RandomBestRecommend
# 62
# RandomBestRecommend
# 64
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 29
# RandomBestRecommend
# 65
# RandomBestRecommend
# 53
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 43
# RandomBestRecommend
# 56
# RandomBestRecommend
# 52
# RandomBestRecommend
# 50
# RandomBestRecommend
# 36
# RandomBestRecommend
# 65
# RandomBestRecommend
# 5
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 58
# RandomBestRecommend
# 5
# RandomBestRecommend
# 63
# RandomBestRecommend
# 19
# RandomBestRecommend
# 38
# RandomBestRecommend
# 8
# RandomBestRecommend
# 0
# RandomBestRecommend
# 58
# RandomBestRecommend
# 0
# RandomBestRecommend
# 23
# RandomBestRecommend
# 49
# RandomBestRecommend
# 43
# RandomBestRecommend
# 46
# RandomBestRecommend
# 43
# RandomBestRecommend
# 55
# RandomBestRecommend
# 54
# RandomBestRecommend
# 51
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 37
# RandomBestRecommend
# 52
# RandomBestRecommend
# 25
# RandomBestRecommend
# 24
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 62
# RandomBestRecommend
# 9
# RandomBestRecommend
# 59
# RandomBestRecommend
# 87
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 30
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 31
# RandomBestRecommend
# 33
# RandomBestRecommend
# 52
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 55
# RandomBestRecommend
# 48
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 22
# RandomBestRecommend
# 28
# RandomBestRecommend
# 18
# RandomBestRecommend
# 55
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 17
# RandomBestRecommend
# 59
# RandomBestRecommend
# 27
# RandomBestRecommend
# 0
# RandomBestRecommend
# ...
# RandomBestRecommend
# 39
# RandomBestRecommend
# 59
# RandomBestRecommend
# 62
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 23
# RandomBestRecommend
# 65
# RandomBestRecommend
# 30
# RandomBestRecommend
# 19
# RandomBestRecommend
# 64
# RandomBestRecommend
# 11
# RandomBestRecommend
# 60
# RandomBestRecommend
# 60
# RandomBestRecommend
# 42
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 48
# RandomBestRecommend
# 3
# RandomBestRecommend
# 58
# RandomBestRecommend
# 2
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 47
# RandomBestRecommend
# 65
# RandomBestRecommend
# 13
# RandomBestRecommend
# 49
# RandomBestRecommend
# 50
# RandomBestRecommend
# 38
# RandomBestRecommend
# 57
# RandomBestRecommend
# 51
# RandomBestRecommend
# 23
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 62
# RandomBestRecommend
# 58
# RandomBestRecommend
# 61
# RandomBestRecommend
# 57
# RandomBestRecommend
# 58
# RandomBestRecommend
# 61
# RandomBestRecommend
# 42
# RandomBestRecommend
# 64
# RandomBestRecommend
# 17
# RandomBestRecommend
# 17
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 46
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 48
# RandomBestRecommend
# 50
# RandomBestRecommend
# 17
# RandomBestRecommend
# 47
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 38
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 47
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 0
# RandomBestRecommend
# 47
# RandomBestRecommend
# 21
# RandomBestRecommend
# 42
# RandomBestRecommend
# 0
# RandomBestRecommend
# 51
# RandomBestRecommend
# 11
# RandomBestRecommend
# 41
# RandomBestRecommend
# 29
# RandomBestRecommend
# 51
# RandomBestRecommend
# 23
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 53
# RandomBestRecommend
# 31
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 13
# RandomBestRecommend
# 54
# RandomBestRecommend
# 70
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 42
# RandomBestRecommend
# 47
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 61
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 13
# RandomBestRecommend
# 33
# RandomBestRecommend
# 60
# RandomBestRecommend
# 64
# RandomBestRecommend
# 24
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 37
# RandomBestRecommend
# 58
# RandomBestRecommend
# 59
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 51
# RandomBestRecommend
# 63
# RandomBestRecommend
# 58
# RandomBestRecommend
# 57
# RandomBestRecommend
# 56
# RandomBestRecommend
# 65
# RandomBestRecommend
# 10
# RandomBestRecommend
# 52
# RandomBestRecommend
# 63
# RandomBestRecommend
# 63
# RandomBestRecommend
# 39
# RandomBestRecommend
# 60
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 44
# RandomBestRecommend
# 60
# RandomBestRecommend
# 52
# RandomBestRecommend
# 19
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 7
# RandomBestRecommend
# 2
# RandomBestRecommend
# 21
# RandomBestRecommend
# 19
# RandomBestRecommend
# 33
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 35
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 22
# RandomBestRecommend
# 0
# RandomBestRecommend
# 27
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 54
# RandomBestRecommend
# 9
# RandomBestRecommend
# 59
# RandomBestRecommend
# 59
# RandomBestRecommend
# 55
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 9
# RandomBestRecommend
# 16
# RandomBestRecommend
# 14
# RandomBestRecommend
# 46
# RandomBestRecommend
# 65
# RandomBestRecommend
# 12
# RandomBestRecommend
# 64
# RandomBestRecommend
# 25
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 41
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 36
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 25
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 57
# RandomBestRecommend
# 43
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 50
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 56
# RandomBestRecommend
# 34
# RandomBestRecommend
# 61
# RandomBestRecommend
# 2
# RandomBestRecommend
# 42
# RandomBestRecommend
# 23
# RandomBestRecommend
# 0
# RandomBestRecommend
# 35
# RandomBestRecommend
# 29
# RandomBestRecommend
# 0
# RandomBestRecommend
# 56
# RandomBestRecommend
# 44
# RandomBestRecommend
# 22
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 82
# RandomBestRecommend
# 38
# RandomBestRecommend
# 63
# RandomBestRecommend
# 53
# RandomBestRecommend
# 46
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 27
# RandomBestRecommend
# 57
# RandomBestRecommend
# 59
# RandomBestRecommend
# 44
# RandomBestRecommend
# 55
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 15
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 60
# RandomBestRecommend
# 62
# RandomBestRecommend
# 57
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 12
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 65
# RandomBestRecommend
# 19
# RandomBestRecommend
# 30
# RandomBestRecommend
# 38
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 33
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 35
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 11
# RandomBestRecommend
# 50
# RandomBestRecommend
# 52
# RandomBestRecommend
# 0
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 44
# RandomBestRecommend
# 49
# RandomBestRecommend
# 62
# RandomBestRecommend
# 58
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 6
# RandomBestRecommend
# 33
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 48
# RandomBestRecommend
# 79
# RandomBestRecommend
# 48
# RandomBestRecommend
# 25
# RandomBestRecommend
# 61
# RandomBestRecommend
# 61
# RandomBestRecommend
# 62
# RandomBestRecommend
# 36
# RandomBestRecommend
# 25
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 55
# RandomBestRecommend
# 62
# RandomBestRecommend
# 58
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 56
# RandomBestRecommend
# 44
# RandomBestRecommend
# 58
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 45
# RandomBestRecommend
# 54
# RandomBestRecommend
# 55
# RandomBestRecommend
# 29
# RandomBestRecommend
# 62
# RandomBestRecommend
# 58
# RandomBestRecommend
# 25
# RandomBestRecommend
# 65
# RandomBestRecommend
# 37
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 18
# RandomBestRecommend
# 65
# RandomBestRecommend
# 38
# RandomBestRecommend
# 50
# RandomBestRecommend
# 25
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 85
# RandomBestRecommend
# 57
# RandomBestRecommend
# 56
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 19
# RandomBestRecommend
# 51
# RandomBestRecommend
# 58
# RandomBestRecommend
# 31
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 62
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 48
# RandomBestRecommend
# 63
# RandomBestRecommend
# 16
# RandomBestRecommend
# 61
# RandomBestRecommend
# 52
# RandomBestRecommend
# 63
# RandomBestRecommend
# 43
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 17
# RandomBestRecommend
# 7
# RandomBestRecommend
# 16
# RandomBestRecommend
# 58
# RandomBestRecommend
# 42
# RandomBestRecommend
# 17
# RandomBestRecommend
# 50
# RandomBestRecommend
# 59
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 0
# RandomBestRecommend
# 41
# RandomBestRecommend
# 42
# RandomBestRecommend
# 59
# RandomBestRecommend
# 59
# RandomBestRecommend
# 63
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 53
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 35
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 64
# RandomBestRecommend
# 32
# RandomBestRecommend
# 64
# RandomBestRecommend
# 56
# RandomBestRecommend
# 64
# RandomBestRecommend
# 12
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 38
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 49
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 54
# RandomBestRecommend
# 60
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 10
# RandomBestRecommend
# 41
# RandomBestRecommend
# 64
# RandomBestRecommend
# 0
# RandomBestRecommend
# 63
# RandomBestRecommend
# 36
# RandomBestRecommend
# 58
# RandomBestRecommend
# 41
# RandomBestRecommend
# 59
# RandomBestRecommend
# 57
# RandomBestRecommend
# 50
# RandomBestRecommend
# 63
# RandomBestRecommend
# 44
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 0
# RandomBestRecommend
# 14
# RandomBestRecommend
# 0
# RandomBestRecommend
# 56
# RandomBestRecommend
# 50
# RandomBestRecommend
# 65
# RandomBestRecommend
# 59
# RandomBestRecommend
# 0
# RandomBestRecommend
# 35
# RandomBestRecommend
# 56
# RandomBestRecommend
# 57
# RandomBestRecommend
# 64
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 4
# RandomBestRecommend
# 64
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 46
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 49
# RandomBestRecommend
# 82
# RandomBestRecommend
# 46
# RandomBestRecommend
# 58
# RandomBestRecommend
# 36
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 53
# RandomBestRecommend
# 0
# RandomBestRecommend
# 43
# RandomBestRecommend
# 56
# RandomBestRecommend
# 7
# RandomBestRecommend
# 20
# RandomBestRecommend
# 54
# RandomBestRecommend
# 65
# RandomBestRecommend
# 56
# RandomBestRecommend
# 25
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 35
# RandomBestRecommend
# 65
# RandomBestRecommend
# 18
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 85
# RandomBestRecommend
# 64
# RandomBestRecommend
# 4
# RandomBestRecommend
# 64
# RandomBestRecommend
# 25
# RandomBestRecommend
# 44
# RandomBestRecommend
# 57
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 60
# RandomBestRecommend
# 50
# RandomBestRecommend
# 62
# RandomBestRecommend
# 47
# RandomBestRecommend
# 0
# RandomBestRecommend
# 24
# RandomBestRecommend
# 58
# RandomBestRecommend
# 39
# RandomBestRecommend
# 20
# RandomBestRecommend
# 65
# RandomBestRecommend
# 20
# RandomBestRecommend
# 48
# RandomBestRecommend
# 64
# RandomBestRecommend
# 39
# RandomBestRecommend
# 64
# RandomBestRecommend
# 46
# RandomBestRecommend
# 0
# RandomBestRecommend
# 42
# RandomBestRecommend
# 59
# RandomBestRecommend
# 56
# RandomBestRecommend
# 65
# RandomBestRecommend
# 42
# RandomBestRecommend
# 13
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 4
# RandomBestRecommend
# 47
# RandomBestRecommend
# 57
# RandomBestRecommend
# 38
# RandomBestRecommend
# 50
# RandomBestRecommend
# 53
# RandomBestRecommend
# 64
# RandomBestRecommend
# 50
# RandomBestRecommend
# 65
# RandomBestRecommend
# 10
# RandomBestRecommend
# 29
# RandomBestRecommend
# 11
# RandomBestRecommend
# 6
# RandomBestRecommend
# 44
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 51
# RandomBestRecommend
# 10
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 64
# RandomBestRecommend
# 12
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 35
# RandomBestRecommend
# 56
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 65
# RandomBestRecommend
# 70
# RandomBestRecommend
# 43
# RandomBestRecommend
# 61
# RandomBestRecommend
# 57
# RandomBestRecommend
# 53
# RandomBestRecommend
# 53
# RandomBestRecommend
# 60
# RandomBestRecommend
# 23
# RandomBestRecommend
# 65
# RandomBestRecommend
# 11
# RandomBestRecommend
# 57
# RandomBestRecommend
# 28
# RandomBestRecommend
# 7
# RandomBestRecommend
# 9
# RandomBestRecommend
# 0
# RandomBestRecommend
# 59
# RandomBestRecommend
# 65
# RandomBestRecommend
# 49
# RandomBestRecommend
# 0
# RandomBestRecommend
# 15
# RandomBestRecommend
# 37
# RandomBestRecommend
# 11
# RandomBestRecommend
# 51
# RandomBestRecommend
# 34
# RandomBestRecommend
# 24
# RandomBestRecommend
# 25
# RandomBestRecommend
# 65
# RandomBestRecommend
# 58
# RandomBestRecommend
# 14
# RandomBestRecommend
# 54
# RandomBestRecommend
# 11
# RandomBestRecommend
# 0
# RandomBestRecommend
# 40
# RandomBestRecommend
# 55
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 57
# RandomBestRecommend
# 44
# RandomBestRecommend
# 56
# RandomBestRecommend
# 51
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 46
# RandomBestRecommend
# 27
# RandomBestRecommend
# 8
# RandomBestRecommend
# 58
# RandomBestRecommend
# 56
# RandomBestRecommend
# 6
# RandomBestRecommend
# 43
# RandomBestRecommend
# 64
# RandomBestRecommend
# 63
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 60
# RandomBestRecommend
# 84
# RandomBestRecommend
# 0
# RandomBestRecommend
# 46
# RandomBestRecommend
# 61
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 60
# RandomBestRecommend
# 33
# RandomBestRecommend
# 54
# RandomBestRecommend
# 77
# RandomBestRecommend
# 65
# RandomBestRecommend
# 22
# RandomBestRecommend
# 12
# RandomBestRecommend
# 61
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 26
# RandomBestRecommend
# 62
# RandomBestRecommend
# 65
# RandomBestRecommend
# 41
# RandomBestRecommend
# 65
# RandomBestRecommend
# 3
# RandomBestRecommend
# 0
# RandomBestRecommend
# 53
# RandomBestRecommend
# 65
# RandomBestRecommend
# 44
# RandomBestRecommend
# 30
# RandomBestRecommend
# 54
# RandomBestRecommend
# 34
# RandomBestRecommend
# 25
# RandomBestRecommend
# 54
# RandomBestRecommend
# 55
# RandomBestRecommend
# 54
# RandomBestRecommend
# 30
# RandomBestRecommend
# 62
# RandomBestRecommend
# 51
# RandomBestRecommend
# 53
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 39
# RandomBestRecommend
# 71
# RandomBestRecommend
# 60
# RandomBestRecommend
# 0
# RandomBestRecommend
# 0
# RandomBestRecommend
# 41
# RandomBestRecommend
# 65
# RandomBestRecommend
# 16
# RandomBestRecommend
# 55
# RandomBestRecommend
# 77
# RandomBestRecommend
# 63
# RandomBestRecommend
# 34
# RandomBestRecommend
# 55
# RandomBestRecommend
# 65
# RandomBestRecommend
# 54
# RandomBestRecommend
# 63
# RandomBestRecommend
# 64
# RandomBestRecommend
# 50
# RandomBestRecommend
# 9
# RandomBestRecommend
# 18
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 59
# RandomBestRecommend
# 15
# RandomBestRecommend
# 65
# RandomBestRecommend
# 61
# RandomBestRecommend
# 62
# RandomBestRecommend
# 59
# RandomBestRecommend
# 43
# RandomBestRecommend
# 50
# RandomBestRecommend
# 63
# RandomBestRecommend
# 46
# RandomBestRecommend
# 0
# RandomBestRecommend
# 55
# RandomBestRecommend
# 63
# RandomBestRecommend
# 50
# RandomBestRecommend
# 42
# RandomBestRecommend
# 40
# RandomBestRecommend
# 44
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 64
# RandomBestRecommend
# 2
# RandomBestRecommend
# 26
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 50
# RandomBestRecommend
# 49
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 61
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 64
# RandomBestRecommend
# 8
# RandomBestRecommend
# 63
# RandomBestRecommend
# 42
# RandomBestRecommend
# 0
# RandomBestRecommend
# 62
# RandomBestRecommend
# 0
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 63
# RandomBestRecommend
# 65
# RandomBestRecommend
# 65
# RandomBestRecommend
# 30
# RandomBestRecommend
# 0

# %%
brunch_recommend_dontread = BrunchRecommend(dontread_user_correction['user_id'].unique(), 
                                            read_check_frame, 
                                            brunch_recommend_read.all_read_set)
variable_user_model = CutoffRecommend(variable_user, cutoff_recommend_count=9, userbased_model=False)
read_model_list = [weekly_model, series_model, dont_series_model, dont_weekly_model, following_favor_many_read_model, 
                   following_favor_repeat_read_model, brunch_model, variable_user_model, regression_user_model, 
                   most_read_article_model]
brunch_recommend_dontread.recommend(read_model_list)
# Out:
# HBox(children=(IntProgress(value=0, max=128), HTML(value='')))
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89
# RandomBestRecommend
# 89

# %%
data_frame_up = brunch_recommend_read.make_result_frame()
data_frame_down = brunch_recommend_dontread.make_result_frame()
data_frame = pd.concat([data_frame_up,data_frame_down],axis=0)
data_frame.shape
# Out:
# (3000, 101)

# %%
dev_user_frame = dev_user.rename(columns={'dev':'user_id'})
sub = dev_user_frame.merge(data_frame, on='user_id', how='left')
sub.to_csv('./submission/recommend_2.txt',index=False,header=False,sep=' ')

# %% [markdown]
# ### Test

# %%
data_frame_up = brunch_recommend_read.make_result_frame()

# %%
h_best = pd.read_csv('./submission/recommend.txt',header=None)
h_best = h_best.rename(columns={0:'user_id'})

# %%
h_best[h_best['user_id'].apply(lambda x: len(set(x.split(' ')))) != 101]

# %%
a = os.listdir('res/read/')

# %%
b = os.listdir('res/read/')

# %%
a
# Out:
# ['2018112114_2018112115',
#  '2019021003_2019021004',
#  '2019011001_2019011002',
#  '2019022219_2019022220',
#  '2018110409_2018110410',
#  '2019010610_2019010611',
#  '2019010921_2019010922',
#  '2018101217_2018101218',
#  '2019021112_2019021113',
#  '2018111807_2018111808',
#  '2019011718_2019011719',
#  '2018122417_2018122418',
#  '2019022320_2019022321',
#  '2019021619_2019021620',
#  '2019021811_2019021812',
#  '2019011813_2019011814',
#  '2018122904_2018122905',
#  '2019022403_2019022404',
#  '2019012401_2019012402',
#  '2018111514_2018111515',
#  '2018100915_2018100916',
#  '2018113009_2018113010',
#  '2018110305_2018110306',
#  '2018102617_2018102618',
#  '2019022512_2019022513',
#  '2019011902_2019011903',
#  '2018121017_2018121018',
#  '2019012318_2019012319',
#  '2018120216_2018120217',
#  '2019021720_2019021721',
#  '2018110910_2018110911',
#  '2019020415_2019020416',
#  '2018102903_2018102904',
#  '2018101511_2018101512',
#  '2018100300_2018100301',
#  '2018120323_2018120400',
#  '2018122311_2018122312',
#  '2018112313_2018112314',
#  '2019021204_2019021205',
#  '2019010506_2019010507',
#  '2018111818_2018111819',
#  '2019011707_2019011708',
#  '2018122408_2018122409',
#  '2018102812_2018102813',
#  '2018112202_2018112203',
#  '2018101208_2018101209',
#  '2018110621_2018110622',
#  '2018120100_2018120101',
#  '2018102111_2018102112',
#  '2019013123_2019020100',
#  '2019022604_2019022605',
#  '2018121919_2018121920',
#  '2018121711_2018121712',
#  '2018111713_2018111714',
#  '2019013106_2019013107',
#  '2018121820_2018121821',
#  '2018121008_2018121009',
#  '2019012307_2019012308',
#  '2018120823_2018120900',
#  '2018102608_2018102609',
#  '2018111602_2018111603',
#  '2018110308_2018110309',
#  '2018101721_2018101722',
#  '2019022206_2019022207',
#  '2018100918_2018100919',
#  '2018120502_2018120503',
#  '2018122121_2018122122',
#  '2018111200_2018111201',
#  '2019012315_2019012316',
#  '2019020914_2019020915',
#  '2018112923_2018113000',
#  '2018110411_2018110412',
#  '2018120413_2018120414',
#  '2018101810_2018101811',
#  '2018102321_2018102322',
#  '2018100702_2018100703',
#  '2019020407_2019020408',
#  '2019021606_2019021607',
#  '2018121521_2018121522',
#  '2018123102_2018123103',
#  '2018100613_2018100614',
#  '2019011715_2019011716',
#  '2018112600_2018112601',
#  '2018113011_2018113012',
#  '2018123013_2018123014',
#  '2019010104_2019010105',
#  '2018122822_2018122823',
#  '2019021809_2019021810',
#  '2018100907_2018100908',
#  '2019010420_2019010421',
#  '2018111116_2018111117',
#  '2019011423_2019011500',
#  '2018110317_2018110318',
#  '2018102605_2018102606',
#  '2018122309_2018122310',
#  '2018120614_2018120615',
#  '2019010519_2019010520',
#  '2019021322_2019021323',
#  '2018110723_2018110800',
#  '2018121005_2018121006',
#  '2018101509_2018101510',
#  '2019022110_2019022111',
#  '2018103014_2018103015',
#  '2019010212_2019010213',
#  '2018112516_2018112517',
#  '2018111923_2018112000',
#  '2018121906_2018121907',
#  '2019013020_2019013021',
#  '2019012023_2019012100',
#  '2019020418_2019020419',
#  '2018101205_2018101206',
#  '2018121709_2018121710',
#  '2019022722_2019022723',
#  '2019013119_2019013120',
#  '2019010303_2019010304',
#  '2019020301_2019020302',
#  '2019012900_2019012901',
#  '2018111815_2018111816',
#  '2019021510_2019021511',
#  '2018122405_2018122406',
#  '2018102109_2018102110',
#  '2018100414_2018100415',
#  '2018101213_2018101214',
#  '2019010315_2019010316',
#  '2019011504_2019011505',
#  '2018122413_2018122414',
#  '2018112411_2018112412',
#  '2018121801_2018121802',
#  '2018110923_2018111000',
#  '2018111803_2018111804',
#  '2018112308_2018112309',
#  '2019021007_2019021008',
#  '2018101302_2018101303',
#  '2019020206_2019020207',
#  '2018120121_2018120122',
#  '2018111912_2018111913',
#  '2018102918_2018102919',
#  '2018122502_2018122503',
#  '2018102613_2018102614',
#  '2018110600_2018110601',
#  '2018121013_2018121014',
#  '2018111011_2018111012',
#  '2019012104_2019012105',
#  '2018120822_2018120823',
#  '2019022407_2019022408',
#  '2018102702_2018102703',
#  '2018100321_2018100322',
#  '2018111708_2018111709',
#  '2019011817_2019011818',
#  '2018121102_2018121103',
#  '2018120309_2018120310',
#  '2018100605_2018100606',
#  '2019012519_2019012520',
#  '2018112723_2018112800',
#  '2019021701_2019021702',
#  '2019011703_2019011704',
#  '2018122614_2018122615',
#  '2018123005_2018123006',
#  '2019020110_2019020111',
#  '2018101014_2018101015',
#  '2019011612_2019011613',
#  '2018102907_2018102908',
#  '2019012420_2019012421',
#  '2018112317_2018112318',
#  '2019021018_2019021019',
#  '2018121214_2018121215',
#  '2019022301_2019022302',
#  '2019012303_2019012304',
#  '2019020722_2019020723',
#  '2019011119_2019011120',
#  '2018100109_2018100110',
#  '2018120405_2018120406',
#  '2019010900_2019010901',
#  '2018102414_2018102415',
#  '2019012212_2019012213',
#  '2019011020_2019011021',
#  '2018110516_2018110517',
#  '2019022418_2019022419',
#  '2018111717_2018111718',
#  '2019011808_2019011809',
#  '2019012921_2019012922',
#  '2018102016_2018102017',
#  '2018120417_2018120418',
#  '2018121616_2018121617',
#  '2019020320_2019020321',
#  '2019011422_2019011423',
#  '2019020219_2019020220',
#  '2018110114_2018110115',
#  '2019013001_2019013002',
#  '2018112409_2018112410',
#  '2019012610_2019012611',
#  '2018111705_2018111706',
#  '2019020512_2019020513',
#  '2018100617_2018100618',
#  '2018101416_2018101417',
#  '2019010318_2019010319',
#  '2018123017_2018123018',
#  '2018122216_2018122217',
#  '2019010401_2019010402',
#  '2019020403_2019020404',
#  '2018120904_2018120905',
#  '2019012022_2019012023',
#  '2018111009_2018111010',
#  '2018102915_2018102916',
#  '2018112305_2018112306',
#  '2019011210_2019011211',
#  '2019021916_2019021917',
#  '2019012506_2019012507',
#  '2018120408_2018120409',
#  '2018100812_2018100813',
#  '2018112621_2018112622',
#  '2018110202_2018110203',
#  '2019022415_2019022416',
#  '2018121500_2018121501',
#  '2019011805_2019011806',
#  '2018112910_2018112911',
#  '2018100903_2018100904',
#  '2018102300_2018102301',
#  '2018110313_2018110314',
#  '2018120311_2018120312',
#  '2018122323_2018122400',
#  '2019011106_2019011107',
#  '2018122823_2018122900',
#  '2019010307_2019010308',
#  '2018123008_2018123009',
#  '2018111221_2018111222',
#  '2018100608_2018100609',
#  '2018122100_2018122101',
#  '2019021015_2019021016',
#  '2018100111_2018100112',
#  '2018101700_2018101701',
#  '2019020604_2019020605',
#  '2018110604_2018110605',
#  '2018111015_2018111016',
#  '2019012100_2019012101',
#  '2018102909_2018102910',
#  '2018102706_2018102707',
#  '2019021221_2019021222',
#  '2018121106_2018121107',
#  '2019013008_2019013009',
#  '2018120307_2018120308',
#  '2019012823_2019012900',
#  '2019012323_2019012400',
#  '2019020313_2019020314',
#  '2019010311_2019010312',
#  '2018121805_2018121806',
#  '2019011500_2019011501',
#  '2018112415_2018112416',
#  '2018101306_2018101307',
#  '2018100107_2018100108',
#  '2019020202_2019020203',
#  '2019022621_2019022622',
#  '2018122506_2018122507',
#  '2018111916_2018111917',
#  '2019010408_2019010409',
#  '2018101622_2018101623',
#  '2018121210_2018121211',
#  '2019022305_2019022306',
#  '2018122022_2018122023',
#  '2019010904_2019010905',
#  '2018120401_2018120402',
#  '2018110403_2018110404',
#  '2019021009_2019021010',
#  '2018102410_2018102411',
#  '2019013017_2019013018',
#  '2018120318_2018120319',
#  '2019012216_2019012217',
#  '2018110512_2018110513',
#  '2018102123_2018102200',
#  '2018100601_2018100602',
#  '2018102222_2018102223',
#  '2019021705_2019021706',
#  '2018122610_2018122611',
#  '2018123001_2018123002',
#  '2018113003_2018113004',
#  '2019020114_2019020115',
#  '2018110219_2018110220',
#  '2018121422_2018121423',
#  '2018101010_2018101011',
#  '2019022409_2019022410',
#  '2019010417_2019010418',
#  '2018110320_2018110321',
#  '2019011616_2019011617',
#  '2018100118_2018100119',
#  '2018122921_2018122922',
#  '2018101523_2018101600',
#  '2019020516_2019020517',
#  '2018121020_2018121021',
#  '2018121808_2018121809',
#  '2018101412_2018101413',
#  '2019021717_2019021718',
#  '2018112418_2018112419',
#  '2018102620_2018102621',
#  '2018122212_2018122213',
#  '2018120900_2018120901',
#  '2019010405_2019010406',
#  '2018102911_2018102912',
#  '2018102719_2018102720',
#  '2018101503_2018101504',
#  '2018121119_2018121120',
#  '2018110722_2018110723',
#  '2018112301_2018112302',
#  '2018122303_2018122304',
#  '2019011214_2019011215',
#  '2018122420_2018122421',
#  '2018111018_2018111019',
#  '2018102012_2018102013',
#  '2019022317_2019022318',
#  '2018101220_2018101221',
#  '2018100223_2018100300',
#  '2018121612_2018121613',
#  '2018110110_2018110111',
#  '2019013005_2019013006',
#  '2018102103_2018102104',
#  '2018101319_2018101320',
#  '2019010309_2019010310',
#  '2019012614_2019012615',
#  '2018111701_2018111702',
#  '2018121703_2018121704',
#  '2019022723_2019022800',
#  '2018122519_2018122520',
#  '2019011102_2019011103',
#  '2018121817_2018121818',
#  '2019021708_2019021709',
#  '2018112407_2018112408',
#  '2019010822_2019010823',
#  '2018122104_2018122105',
#  '2019011013_2019011014',
#  '2019021011_2019021012',
#  '2018100115_2018100116',
#  '2018101704_2018101705',
#  '2019020600_2019020601',
#  '2019012502_2019012503',
#  '2019021912_2019021913',
#  '2019010121_2019010122',
#  '2018100816_2018100817',
#  '2018111007_2018111008',
#  '2019022308_2019022309',
#  '2018110206_2018110207',
#  '2019011801_2019011802',
#  '2019021803_2019021804',
#  '2019020923_2019021000',
#  '2018112914_2018112915',
#  '2019012413_2019012414',
#  '2019022411_2019022412',
#  '2018121504_2018121505',
#  '2018102304_2018102305',
#  '2018120315_2018120316',
#  '2019012405_2019012406',
#  '2018111510_2018111511',
#  '2019021815_2019021816',
#  '2018122900_2018122901',
#  '2018100719_2018100720',
#  '2018100911_2018100912',
#  '2019011709_2019011710',
#  '2018120303_2018120304',
#  '2018110301_2018110302',
#  '2018123119_2018123120',
#  '2018112722_2018112723',
#  '2018123020_2018123021',
#  '2019011906_2019011907',
#  '2019022516_2019022517',
#  '2019021923_2019022000',
#  '2018110418_2018110419',
#  '2018122023_2018122100',
#  '2018100620_2018100621',
#  '2018101623_2018101700',
#  '2018120212_2018120213',
#  '2018112110_2018112111',
#  '2019011005_2019011006',
#  '2018100103_2018100104',
#  '2019012309_2019012310',
#  '2018111322_2018111323',
#  '2019020723_2019020800',
#  '2018120519_2018120520',
#  '2019022823_2019030100',
#  '2019010614_2019010615',
#  '2019021116_2019021117',
#  '2018120420_2018120421',
#  '2019020317_2019020318',
#  '2018121423_2018121500',
#  '2018113018_2018113019',
#  '2018102223_2018102300',
#  '2019012822_2019012823',
#  '2018120104_2018120105',
#  '2019013013_2019013014',
#  '2018111809_2018111810',
#  '2018102115_2018102116',
#  '2019022600_2019022601',
#  '2018121715_2018121716',
#  '2019013102_2019013103',
#  '2019011521_2019011522',
#  '2018110407_2018110408',
#  '2018111606_2018111607',
#  '2019020411_2019020412',
#  '2019010413_2019010414',
#  '2018110914_2018110915',
#  '2018101515_2018101516',
#  '2018100304_2018100305',
#  '2018122315_2018122316',
#  '2019021200_2019021201',
#  '2019012121_2019012122',
#  '2019010502_2019010503',
#  '2018102816_2018102817',
#  '2019020308_2019020309',
#  '2018113007_2018113008',
#  '2018112206_2018112207',
#  '2018100706_2018100707',
#  '2019021602_2019021603',
#  '2018101507_2018101508',
#  '2019011820_2019011821',
#  '2018123106_2018123107',
#  '2019010823_2019010900',
#  '2018122307_2018122308',
#  '2019011008_2019011009',
#  '2019011711_2019011712',
#  '2019011919_2019011920',
#  '2019021713_2019021714',
#  '2018112604_2018112605',
#  '2018100909_2018100910',
#  '2018113015_2018113016',
#  '2019010100_2019010101',
#  '2019020621_2019020622',
#  '2019022202_2019022203',
#  '2018102107_2018102108',
#  '2018120506_2018120507',
#  '2019012408_2019012409',
#  '2018121707_2018121708',
#  '2019021818_2019021819',
#  '2018111204_2018111205',
#  '2019012311_2019012312',
#  '2019022313_2019022314',
#  '2019010323_2019010400',
#  '2018110415_2018110416',
#  '2019020910_2019020911',
#  '2018101814_2018101815',
#  '2018122318_2018122319',
#  '2019011017_2019011018',
#  '2018111720_2018111721',
#  '2019010216_2019010217',
#  '2018101518_2018101519',
#  '2018121902_2018121903',
#  '2018112512_2018112513',
#  '2018100123_2018100200',
#  '2018101201_2018101202',
#  '2019020305_2019020306',
#  '2019021514_2019021515',
#  '2018112403_2018112404',
#  '2018122401_2018122402',
#  '2019012904_2019012905',
#  '2018111811_2018111812',
#  '2018111619_2018111620',
#  '2018121813_2018121814',
#  '2018100410_2018100411',
#  '2019012417_2019012418',
#  '2018121718_2018121719',
#  '2019021807_2019021808',
#  '2018112320_2018112321',
#  '2018111112_2018111113',
#  '2018120921_2018120922',
#  '2018102118_2018102119',
#  '2018100222_2018100223',
#  '2018102601_2018102602',
#  '2018120610_2018120611',
#  '2018112219_2018112220',
#  '2018111003_2018111004',
#  '2018121001_2018121002',
#  '2019022114_2019022115',
#  '2018103010_2018103011',
#  '2019020409_2019020410',
#  '2019012117_2019012118',
#  '2018121218_2018121219',
#  '2018112620_2018112621',
#  '2018111412_2018111413',
#  '2018102418_2018102419',
#  '2018122802_2018122803',
#  '2018100722_2018100723',
#  '2018102301_2018102302',
#  '2018120310_2018120311',
#  '2019011804_2019011805',
#  '2018123122_2018123123',
#  '2018122913_2018122914',
#  '2018112719_2018112720',
#  '2018112911_2018112912',
#  '2019022414_2019022415',
#  '2018121501_2018121502',
#  '2018111503_2018111504',
#  '2019020109_2019020110',
#  '2018122618_2018122619',
#  '2018110223_2018110300',
#  '2019011517_2019011518',
#  '2018111220_2018111221',
#  '2019010716_2019010717',
#  '2018101018_2018101019',
#  '2018112012_2018112013',
#  '2018101701_2018101702',
#  '2019020605_2019020606',
#  '2018122101_2018122102',
#  '2018112103_2018112104',
#  '2019021014_2019021015',
#  '2018111319_2018111320',
#  '2018120522_2018120523',
#  '2018100110_2018100111',
#  '2019020321_2019020322',
#  '2018102407_2018102408',
#  '2019022702_2019022703',
#  '2019012920_2019012921',
#  '2019012108_2019012109',
#  '2018121207_2018121208',
#  '2019022613_2019022614',
#  '2019012819_2019012820',
#  '2019012611_2019012612',
#  '2018111704_2018111705',
#  '2018110115_2018110116',
#  '2019013000_2019013001',
#  '2018100206_2018100207',
#  '2018101007_2018101008',
#  '2019021302_2019021303',
#  '2018110816_2018110817',
#  '2018122607_2018122608',
#  '2019011508_2019011509',
#  '2018112304_2018112305',
#  '2019021213_2019021214',
#  '2019011211_2019011212',
#  '2018120905_2018120906',
#  '2019010400_2019010401',
#  '2018102914_2018102915',
#  '2018123004_2018123005',
#  '2019011922_2019011923',
#  '2019010113_2019010114',
#  '2019020111_2019020112',
#  '2018101015_2018101016',
#  '2018112909_2018112910',
#  '2018100604_2018100605',
#  '2019021700_2019021701',
#  '2018122615_2018122616',
#  '2019012421_2019012422',
#  '2018120917_2018120918',
#  '2019020608_2019020609',
#  '2018112706_2018112707',
#  '2019010901_2019010902',
#  '2019020903_2019020904',
#  '2018120404_2018120405',
#  '2018102415_2018102416',
#  '2018121215_2018121216',
#  '2019022300_2019022301',
#  '2019020812_2019020813',
#  '2019011021_2019011022',
#  '2018101916_2018101917',
#  '2018110107_2018110108',
#  '2018111306_2018111307',
#  '2018121800_2018121801',
#  '2019011505_2019011506',
#  '2018112410_2018112411',
#  '2018100403_2018100404',
#  '2019012609_2019012610',
#  '2018111622_2018111623',
#  '2019010314_2019010315',
#  '2019021416_2019021417',
#  '2018112123_2018112200',
#  '2019012806_2019012807',
#  '2018120120_2018120121',
#  '2018120908_2018120909',
#  '2018100512_2018100513',
#  '2019020617_2019020618',
#  '2018111010_2018111011',
#  '2019012105_2019012106',
#  '2018103003_2018103004',
#  '2018100219_2018100220',
#  '2019011209_2019011210',
#  '2018110601_2018110602',
#  '2018120603_2018120604',
#  '2018112222_2018112223',
#  '2018111523_2018111600',
#  '2019022016_2019022017',
#  '2018110118_2018110119',
#  '2018103112_2018103113',
#  '2018100320_2018100321',
#  '2018120712_2018120713',
#  '2019012002_2019012003',
#  '2019010421_2019010422',
#  '2018111507_2018111508',
#  '2018122917_2018122918',
#  '2019022608_2019022609',
#  '2018110706_2018110707',
#  '2018121004_2018121005',
#  '2019022111_2019022112',
#  '2019012113_2019012114',
#  '2018110909_2018110910',
#  '2018103015_2018103016',
#  '2018102604_2018102605',
#  '2018120615_2018120616',
#  '2019022812_2019022813',
#  '2019013021_2019013022',
#  '2019011402_2019011403',
#  '2019021208_2019021209',
#  '2018112107_2018112108',
#  '2019021511_2019021512',
#  '2019011513_2019011514',
#  '2018122404_2018122405',
#  '2019012901_2019012902',
#  '2018111814_2018111815',
#  '2018100415_2018100416',
#  '2018101204_2018101205',
#  '2019020300_2019020301',
#  '2019010806_2019010807',
#  '2018122120_2018122121',
#  '2018110123_2018110200',
#  '2018111518_2018111519',
#  '2018122908_2018122909',
#  '2019022617_2019022618',
#  '2018102512_2018102513',
#  '2018101720_2018101721',
#  '2018121312_2018121313',
#  '2018110410_2018110411',
#  '2019020915_2019020916',
#  '2018102403_2018102404',
#  '2018101619_2018101620',
#  '2018101811_2018101812',
#  '2019010609_2019010610',
#  '2018121203_2018121204',
#  '2018111201_2018111202',
#  '2019012314_2019012315',
#  '2018122019_2018122020',
#  '2018121520_2018121521',
#  '2019021217_2019021218',
#  '2018101112_2018101113',
#  '2018112118_2018112119',
#  '2018102320_2018102321',
#  '2018122712_2018122713',
#  '2018113010_2018113011',
#  '2019010105_2019010106',
#  '2018102219_2018102220',
#  '2018101003_2018101004',
#  '2018110222_2018110223',
#  '2018121419_2018121420',
#  '2019011714_2019011715',
#  '2018122603_2018122604',
#  '2018112601_2018112602',
#  '2018100301_2018100302',
#  '2018102722_2018102723',
#  '2018122310_2018122311',
#  '2019021205_2019021206',
#  '2019020414_2019020415',
#  '2018121122_2018121123',
#  '2018110911_2018110912',
#  '2018110719_2018110720',
#  '2018120913_2018120914',
#  '2019022109_2019022110',
#  '2018101510_2018101511',
#  '2018111623_2018111700',
#  '2019010117_2019010118',
#  '2018110620_2018110621',
#  '2019011316_2019011317',
#  '2018100418_2018100419',
#  '2018120802_2018120803',
#  '2018101322_2018101323',
#  '2019022605_2019022606',
#  '2018121710_2018121711',
#  '2018122522_2018122523',
#  '2018110103_2018110104',
#  '2018120101_2018120102',
#  '2018102110_2018102111',
#  '2019021509_2019021510',
#  '2018120618_2018120619',
#  '2019020907_2019020908',
#  '2018112223_2018112300',
#  '2019012716_2019012717',
#  '2018121821_2018121822',
#  '2018103018_2018103019',
#  '2019010611_2019010612',
#  '2019010819_2019010820',
#  '2019020613_2019020614',
#  '2018101809_2018101810',
#  '2018112115_2018112116',
#  '2019011000_2019011001',
#  '2018101606_2018101607',
#  '2019020702_2019020703',
#  '2018100407_2018100408',
#  '2019022321_2019022322',
#  '2018122006_2018122007',
#  '2019010920_2019010921',
#  '2019010108_2019010109',
#  '2018110304_2018110305',
#  '2019012400_2019012401',
#  '2018111515_2018111516',
#  '2019021810_2019021811',
#  '2018122905_2018122906',
#  '2018100914_2018100915',
#  '2018102206_2018102207',
#  '2019021721_2019021722',
#  '2018103007_2018103008',
#  '2018112816_2018112817',
#  '2018121406_2018121407',
#  '2018120607_2018120608',
#  '2019020918_2019020919',
#  '2019011406_2019011407',
#  '2019022816_2019022817',
#  '2018110918_2018110919',
#  '2019010607_2019010608',
#  '2018100308_2018100309',
#  '2018111721_2018111722',
#  '2019012905_2019012906',
#  '2018111810_2018111811',
#  '2019021515_2019021516',
#  '2018122400_2018122401',
#  '2018102923_2018103000',
#  '2018100411_2018100412',
#  '2018101200_2018101201',
#  '2019020304_2019020305',
#  '2018120920_2018120921',
#  '2019012006_2019012007',
#  '2018120108_2018120109',
#  '2018112321_2018112322',
#  '2018110702_2018110703',
#  '2018121000_2018121001',
#  '2019022115_2019022116',
#  '2018103011_2018103012',
#  '2018102600_2018102601',
#  '2018120819_2018120820',
#  '2018120611_2018120612',
#  '2018110613_2018110614',
#  '2019011821_2019011822',
#  '2018100317_2018100318',
#  '2018101116_2018101117',
#  '2019022223_2019022300',
#  '2018110907_2018110908',
#  '2019010618_2019010619',
#  '2018122716_2018122717',
#  '2018113014_2018113015',
#  '2019020103_2019020104',
#  '2019010101_2019010102',
#  '2019012522_2019012523',
#  '2018111509_2018111510',
#  '2018100723_2018100800',
#  '2019011710_2019011711',
#  '2018112605_2018112606',
#  '2019010802_2019010803',
#  '2018102516_2018102517',
#  '2018101923_2018102000',
#  '2018120117_2018120118',
#  '2019021623_2019021700',
#  '2018121316_2018121317',
#  '2019020620_2019020621',
#  '2019020719_2019020720',
#  '2019020911_2019020912',
#  '2019010913_2019010914',
#  '2019011122_2019011123',
#  '2018110414_2018110415',
#  '2018101815_2018101816',
#  '2018112109_2018112110',
#  '2018111205_2018111206',
#  '2019012310_2019012311',
#  '2019012603_2019012604',
#  '2019022601_2019022602',
#  '2018121714_2018121715',
#  '2019011419_2019011420',
#  '2019020222_2019020223',
#  '2018120105_2018120106',
#  '2018100409_2018100410',
#  '2018102114_2018102115',
#  '2018101807_2018101808',
#  '2019012712_2019012713',
#  '2019011520_2019011521',
#  '2019022118_2019022119',
#  '2018111217_2018111218',
#  '2018100305_2018100306',
#  '2018120609_2018120610',
#  '2019012019_2019012020',
#  '2018122314_2018122315',
#  '2019011203_2019011204',
#  '2019021201_2019021202',
#  '2018110915_2018110916',
#  '2019020410_2019020411',
#  '2018103009_2018103010',
#  '2018101514_2018101515',
#  '2019011312_2019011313',
#  '2019020123_2019020200',
#  '2019012120_2019012121',
#  '2018120806_2018120807',
#  '2018112617_2018112618',
#  '2019012908_2019012909',
#  '2019021518_2019021519',
#  '2018102313_2018102314',
#  '2018110300_2018110301',
#  '2019021814_2019021815',
#  '2018112903_2018112904',
#  '2018122901_2018122902',
#  '2019012404_2019012405',
#  '2018111511_2018111512',
#  '2018121513_2018121514',
#  '2018100910_2018100911',
#  '2018102202_2018102203',
#  '2019022107_2019022108',
#  '2018111208_2018111209',
#  '2018100621_2018100622',
#  '2018101818_2018101819',
#  '2018121402_2018121403',
#  '2018123021_2018123022',
#  '2018112812_2018112813',
#  '2018101713_2018101714',
#  '2019010615_2019010616',
#  '2018112111_2018112112',
#  '2018122113_2018122114',
#  '2019011004_2019011005',
#  '2019020909_2019020910',
#  '2018112608_2018112609',
#  '2019012917_2019012918',
#  '2018101602_2018101603',
#  '2019021507_2019021508',
#  '2019020706_2019020707',
#  '2018120421_2018120422',
#  '2018122002_2018122003',
#  '2019010712_2019010713',
#  '2018112016_2018112017',
#  '2019021523_2019021600',
#  '2019020118_2019020119',
#  '2018121209_2018121210',
#  '2018101705_2018101706',
#  '2019022222_2019022223',
#  '2019020601_2019020602',
#  '2019010603_2019010604',
#  '2018102409_2018102410',
#  '2018122105_2018122106',
#  '2019021010_2019021011',
#  '2018100114_2018100115',
#  '2019010120_2019010121',
#  '2018122806_2018122807',
#  '2019022123_2019022200',
#  '2018111416_2018111417',
#  '2018110617_2018110618',
#  '2019010908_2019010909',
#  '2018122609_2018122610',
#  '2018102305_2018102306',
#  '2018120314_2018120315',
#  '2019021622_2019021623',
#  '2019022410_2019022411',
#  '2018101009_2018101010',
#  '2018121505_2018121506',
#  '2019011800_2019011801',
#  '2018112915_2018112916',
#  '2018102621_2018102622',
#  '2019020107_2019020108',
#  '2018100202_2018100203',
#  '2019021306_2019021307',
#  '2018121021_2018121022',
#  '2018110812_2018110813',
#  '2018100313_2018100314',
#  '2018112300_2018112301',
#  '2019011215_2019011216',
#  '2019010404_2019010405',
#  '2018120901_2018120902',
#  '2018110903_2018110904',
#  '2018102910_2018102911',
#  '2018101221_2018101222',
#  '2018110608_2018110609',
#  '2019010917_2019010918',
#  '2019022706_2019022707',
#  '2018122421_2018122422',
#  '2019012615_2019012616',
#  '2018111700_2018111701',
#  '2018120113_2018120114',
#  '2018110111_2018110112',
#  '2018121922_2018121923',
#  '2019013004_2019013005',
#  '2018120400_2018120401',
#  '2019010905_2019010906',
#  '2018102411_2018102412',
#  '2018101803_2018101804',
#  '2018100923_2018101000',
#  '2018111213_2018111214',
#  '2018121211_2018121212',
#  '2019022304_2019022305',
#  '2019020816_2019020817',
#  '2018121508_2018121509',
#  '2018101912_2018101913',
#  '2018112918_2018112919',
#  '2019012607_2019012608',
#  '2018102308_2018102309',
#  '2018111302_2018111303',
#  '2018123000_2018123001',
#  '2019020115_2019020116',
#  '2018101011_2018101012',
#  '2018100600_2018100601',
#  '2019021704_2019021705',
#  '2018112613_2018112614',
#  '2018122611_2018122612',
#  '2018122819_2018122820',
#  '2018122920_2018122921',
#  '2019011207_2019011208',
#  '2018122108_2018122109',
#  '2018112702_2018112703',
#  '2018110321_2018110322',
#  '2018101708_2018101709',
#  '2019010522_2019010523',
#  '2019021319_2019021320',
#  '2018111014_2018111015',
#  '2019012101_2019012102',
#  '2019022103_2019022104',
#  '2018102723_2018102800',
#  '2018110605_2018110606',
#  '2019022012_2019022013',
#  '2018102317_2018102318',
#  '2018103116_2018103117',
#  '2018121517_2018121518',
#  '2018112907_2018112908',
#  '2019020223_2019020300',
#  '2019012618_2019012619',
#  '2018120716_2018120717',
#  '2019021220_2019021221',
#  '2019011501_2019011502',
#  '2019021503_2019021504',
#  '2018112414_2018112415',
#  '2019012913_2019012914',
#  '2019022719_2019022720',
#  '2019013122_2019013123',
#  '2018121804_2018121805',
#  '2018110109_2018110110',
#  '2019010310_2019010311',
#  '2019012802_2019012803',
#  '2019021412_2019021413',
#  '2018101717_2018101718',
#  '2018100516_2018100517',
#  '2019011218_2019011219',
#  '2018122117_2018122118',
#  '2019022620_2019022621',
#  '2019011713_2019011714',
#  '2019021711_2019021712',
#  '2019021919_2019021920',
#  '2018122604_2018122605',
#  '2018100615_2018100616',
#  '2018101004_2018101005',
#  '2018123015_2018123016',
#  '2019020100_2019020101',
#  '2019011602_2019011603',
#  '2018102917_2018102918',
#  '2018112307_2018112308',
#  '2019020823_2019020900',
#  '2019021008_2019021009',
#  '2019021820_2019021821',
#  '2018121204_2018121205',
#  '2019012313_2019012314',
#  '2019022311_2019022312',
#  '2019020323_2019020400',
#  '2018102404_2018102405',
#  '2018120415_2018120416',
#  '2019010910_2019010911',
#  '2019010621_2019010622',
#  '2019012202_2019012203',
#  '2019022408_2019022409',
#  '2018111707_2018111708',
#  '2019011818_2019011819',
#  '2018110506_2018110507',
#  '2019010305_2019010306',
#  '2018101203_2018101204',
#  '2018102019_2018102020',
#  '2019013009_2019013010',
#  '2019011514_2019011515',
#  '2018112401_2018112402',
#  '2018122403_2018122404',
#  '2018111813_2018111814',
#  '2018121811_2018121812',
#  '2018121619_2018121620',
#  '2018121720_2018121721',
#  '2019020216_2019020217',
#  '2018112318_2018112319',
#  '2018101312_2018101313',
#  '2019021017_2019021018',
#  '2018102120_2018102121',
#  '2018111902_2018111903',
#  '2018102908_2018102909',
#  '2018122512_2018122513',
#  '2018110610_2018110611',
#  '2018101419_2018101420',
#  '2018102603_2018102604',
#  '2019010409_2019010410',
#  '2018122219_2018122220',
#  '2018111001_2018111002',
#  '2018121003_2018121004',
#  '2019012114_2019012115',
#  '2018122320_2018122321',
#  '2018102712_2018102713',
#  '2019022417_2019022418',
#  '2018111718_2018111719',
#  '2019011807_2019011808',
#  '2018101520_2018101521',
#  '2018121112_2018121113',
#  '2018110921_2018110922',
#  '2018120418_2018120419',
#  '2018112023_2018112100',
#  '2018100802_2018100803',
#  '2019021906_2019021907',
#  '2018113020_2018113021',
#  '2019011923_2019012000',
#  '2019012516_2019012517',
#  '2018110212_2018110213',
#  '2018101122_2018101123',
#  '2018100913_2018100914',
#  '2019022405_2019022406',
#  '2018121510_2018121511',
#  ...]

# %%
b
# Out:
# ['2018112114_2018112115',
#  '2019021003_2019021004',
#  '2019011001_2019011002',
#  '2019022219_2019022220',
#  '2018110409_2018110410',
#  '2019010610_2019010611',
#  '2019010921_2019010922',
#  '2018101217_2018101218',
#  '2019021112_2019021113',
#  '2018111807_2018111808',
#  '2019011718_2019011719',
#  '2018122417_2018122418',
#  '2019022320_2019022321',
#  '2019021619_2019021620',
#  '2019021811_2019021812',
#  '2019011813_2019011814',
#  '2018122904_2018122905',
#  '2019022403_2019022404',
#  '2019012401_2019012402',
#  '2018111514_2018111515',
#  '2018100915_2018100916',
#  '2018113009_2018113010',
#  '2018110305_2018110306',
#  '2018102617_2018102618',
#  '2019022512_2019022513',
#  '2019011902_2019011903',
#  '2018121017_2018121018',
#  '2019012318_2019012319',
#  '2018120216_2018120217',
#  '2019021720_2019021721',
#  '2018110910_2018110911',
#  '2019020415_2019020416',
#  '2018102903_2018102904',
#  '2018101511_2018101512',
#  '2018100300_2018100301',
#  '2018120323_2018120400',
#  '2018122311_2018122312',
#  '2018112313_2018112314',
#  '2019021204_2019021205',
#  '2019010506_2019010507',
#  '2018111818_2018111819',
#  '2019011707_2019011708',
#  '2018122408_2018122409',
#  '2018102812_2018102813',
#  '2018112202_2018112203',
#  '2018101208_2018101209',
#  '2018110621_2018110622',
#  '2018120100_2018120101',
#  '2018102111_2018102112',
#  '2019013123_2019020100',
#  '2019022604_2019022605',
#  '2018121919_2018121920',
#  '2018121711_2018121712',
#  '2018111713_2018111714',
#  '2019013106_2019013107',
#  '2018121820_2018121821',
#  '2018121008_2018121009',
#  '2019012307_2019012308',
#  '2018120823_2018120900',
#  '2018102608_2018102609',
#  '2018111602_2018111603',
#  '2018110308_2018110309',
#  '2018101721_2018101722',
#  '2019022206_2019022207',
#  '2018100918_2018100919',
#  '2018120502_2018120503',
#  '2018122121_2018122122',
#  '2018111200_2018111201',
#  '2019012315_2019012316',
#  '2019020914_2019020915',
#  '2018112923_2018113000',
#  '2018110411_2018110412',
#  '2018120413_2018120414',
#  '2018101810_2018101811',
#  '2018102321_2018102322',
#  '2018100702_2018100703',
#  '2019020407_2019020408',
#  '2019021606_2019021607',
#  '2018121521_2018121522',
#  '2018123102_2018123103',
#  '2018100613_2018100614',
#  '2019011715_2019011716',
#  '2018112600_2018112601',
#  '2018113011_2018113012',
#  '2018123013_2018123014',
#  '2019010104_2019010105',
#  '2018122822_2018122823',
#  '2019021809_2019021810',
#  '2018100907_2018100908',
#  '2019010420_2019010421',
#  '2018111116_2018111117',
#  '2019011423_2019011500',
#  '2018110317_2018110318',
#  '2018102605_2018102606',
#  '2018122309_2018122310',
#  '2018120614_2018120615',
#  '2019010519_2019010520',
#  '2019021322_2019021323',
#  '2018110723_2018110800',
#  '2018121005_2018121006',
#  '2018101509_2018101510',
#  '2019022110_2019022111',
#  '2018103014_2018103015',
#  '2019010212_2019010213',
#  '2018112516_2018112517',
#  '2018111923_2018112000',
#  '2018121906_2018121907',
#  '2019013020_2019013021',
#  '2019012023_2019012100',
#  '2019020418_2019020419',
#  '2018101205_2018101206',
#  '2018121709_2018121710',
#  '2019022722_2019022723',
#  '2019013119_2019013120',
#  '2019010303_2019010304',
#  '2019020301_2019020302',
#  '2019012900_2019012901',
#  '2018111815_2018111816',
#  '2019021510_2019021511',
#  '2018122405_2018122406',
#  '2018102109_2018102110',
#  '2018100414_2018100415',
#  '2018101213_2018101214',
#  '2019010315_2019010316',
#  '2019011504_2019011505',
#  '2018122413_2018122414',
#  '2018112411_2018112412',
#  '2018121801_2018121802',
#  '2018110923_2018111000',
#  '2018111803_2018111804',
#  '2018112308_2018112309',
#  '2019021007_2019021008',
#  '2018101302_2018101303',
#  '2019020206_2019020207',
#  '2018120121_2018120122',
#  '2018111912_2018111913',
#  '2018102918_2018102919',
#  '2018122502_2018122503',
#  '2018102613_2018102614',
#  '2018110600_2018110601',
#  '2018121013_2018121014',
#  '2018111011_2018111012',
#  '2019012104_2019012105',
#  '2018120822_2018120823',
#  '2019022407_2019022408',
#  '2018102702_2018102703',
#  '2018100321_2018100322',
#  '2018111708_2018111709',
#  '2019011817_2019011818',
#  '2018121102_2018121103',
#  '2018120309_2018120310',
#  '2018100605_2018100606',
#  '2019012519_2019012520',
#  '2018112723_2018112800',
#  '2019021701_2019021702',
#  '2019011703_2019011704',
#  '2018122614_2018122615',
#  '2018123005_2018123006',
#  '2019020110_2019020111',
#  '2018101014_2018101015',
#  '2019011612_2019011613',
#  '2018102907_2018102908',
#  '2019012420_2019012421',
#  '2018112317_2018112318',
#  '2019021018_2019021019',
#  '2018121214_2018121215',
#  '2019022301_2019022302',
#  '2019012303_2019012304',
#  '2019020722_2019020723',
#  '2019011119_2019011120',
#  '2018100109_2018100110',
#  '2018120405_2018120406',
#  '2019010900_2019010901',
#  '2018102414_2018102415',
#  '2019012212_2019012213',
#  '2019011020_2019011021',
#  '2018110516_2018110517',
#  '2019022418_2019022419',
#  '2018111717_2018111718',
#  '2019011808_2019011809',
#  '2019012921_2019012922',
#  '2018102016_2018102017',
#  '2018120417_2018120418',
#  '2018121616_2018121617',
#  '2019020320_2019020321',
#  '2019011422_2019011423',
#  '2019020219_2019020220',
#  '2018110114_2018110115',
#  '2019013001_2019013002',
#  '2018112409_2018112410',
#  '2019012610_2019012611',
#  '2018111705_2018111706',
#  '2019020512_2019020513',
#  '2018100617_2018100618',
#  '2018101416_2018101417',
#  '2019010318_2019010319',
#  '2018123017_2018123018',
#  '2018122216_2018122217',
#  '2019010401_2019010402',
#  '2019020403_2019020404',
#  '2018120904_2018120905',
#  '2019012022_2019012023',
#  '2018111009_2018111010',
#  '2018102915_2018102916',
#  '2018112305_2018112306',
#  '2019011210_2019011211',
#  '2019021916_2019021917',
#  '2019012506_2019012507',
#  '2018120408_2018120409',
#  '2018100812_2018100813',
#  '2018112621_2018112622',
#  '2018110202_2018110203',
#  '2019022415_2019022416',
#  '2018121500_2018121501',
#  '2019011805_2019011806',
#  '2018112910_2018112911',
#  '2018100903_2018100904',
#  '2018102300_2018102301',
#  '2018110313_2018110314',
#  '2018120311_2018120312',
#  '2018122323_2018122400',
#  '2019011106_2019011107',
#  '2018122823_2018122900',
#  '2019010307_2019010308',
#  '2018123008_2018123009',
#  '2018111221_2018111222',
#  '2018100608_2018100609',
#  '2018122100_2018122101',
#  '2019021015_2019021016',
#  '2018100111_2018100112',
#  '2018101700_2018101701',
#  '2019020604_2019020605',
#  '2018110604_2018110605',
#  '2018111015_2018111016',
#  '2019012100_2019012101',
#  '2018102909_2018102910',
#  '2018102706_2018102707',
#  '2019021221_2019021222',
#  '2018121106_2018121107',
#  '2019013008_2019013009',
#  '2018120307_2018120308',
#  '2019012823_2019012900',
#  '2019012323_2019012400',
#  '2019020313_2019020314',
#  '2019010311_2019010312',
#  '2018121805_2018121806',
#  '2019011500_2019011501',
#  '2018112415_2018112416',
#  '2018101306_2018101307',
#  '2018100107_2018100108',
#  '2019020202_2019020203',
#  '2019022621_2019022622',
#  '2018122506_2018122507',
#  '2018111916_2018111917',
#  '2019010408_2019010409',
#  '2018101622_2018101623',
#  '2018121210_2018121211',
#  '2019022305_2019022306',
#  '2018122022_2018122023',
#  '2019010904_2019010905',
#  '2018120401_2018120402',
#  '2018110403_2018110404',
#  '2019021009_2019021010',
#  '2018102410_2018102411',
#  '2019013017_2019013018',
#  '2018120318_2018120319',
#  '2019012216_2019012217',
#  '2018110512_2018110513',
#  '2018102123_2018102200',
#  '2018100601_2018100602',
#  '2018102222_2018102223',
#  '2019021705_2019021706',
#  '2018122610_2018122611',
#  '2018123001_2018123002',
#  '2018113003_2018113004',
#  '2019020114_2019020115',
#  '2018110219_2018110220',
#  '2018121422_2018121423',
#  '2018101010_2018101011',
#  '2019022409_2019022410',
#  '2019010417_2019010418',
#  '2018110320_2018110321',
#  '2019011616_2019011617',
#  '2018100118_2018100119',
#  '2018122921_2018122922',
#  '2018101523_2018101600',
#  '2019020516_2019020517',
#  '2018121020_2018121021',
#  '2018121808_2018121809',
#  '2018101412_2018101413',
#  '2019021717_2019021718',
#  '2018112418_2018112419',
#  '2018102620_2018102621',
#  '2018122212_2018122213',
#  '2018120900_2018120901',
#  '2019010405_2019010406',
#  '2018102911_2018102912',
#  '2018102719_2018102720',
#  '2018101503_2018101504',
#  '2018121119_2018121120',
#  '2018110722_2018110723',
#  '2018112301_2018112302',
#  '2018122303_2018122304',
#  '2019011214_2019011215',
#  '2018122420_2018122421',
#  '2018111018_2018111019',
#  '2018102012_2018102013',
#  '2019022317_2019022318',
#  '2018101220_2018101221',
#  '2018100223_2018100300',
#  '2018121612_2018121613',
#  '2018110110_2018110111',
#  '2019013005_2019013006',
#  '2018102103_2018102104',
#  '2018101319_2018101320',
#  '2019010309_2019010310',
#  '2019012614_2019012615',
#  '2018111701_2018111702',
#  '2018121703_2018121704',
#  '2019022723_2019022800',
#  '2018122519_2018122520',
#  '2019011102_2019011103',
#  '2018121817_2018121818',
#  '2019021708_2019021709',
#  '2018112407_2018112408',
#  '2019010822_2019010823',
#  '2018122104_2018122105',
#  '2019011013_2019011014',
#  '2019021011_2019021012',
#  '2018100115_2018100116',
#  '2018101704_2018101705',
#  '2019020600_2019020601',
#  '2019012502_2019012503',
#  '2019021912_2019021913',
#  '2019010121_2019010122',
#  '2018100816_2018100817',
#  '2018111007_2018111008',
#  '2019022308_2019022309',
#  '2018110206_2018110207',
#  '2019011801_2019011802',
#  '2019021803_2019021804',
#  '2019020923_2019021000',
#  '2018112914_2018112915',
#  '2019012413_2019012414',
#  '2019022411_2019022412',
#  '2018121504_2018121505',
#  '2018102304_2018102305',
#  '2018120315_2018120316',
#  '2019012405_2019012406',
#  '2018111510_2018111511',
#  '2019021815_2019021816',
#  '2018122900_2018122901',
#  '2018100719_2018100720',
#  '2018100911_2018100912',
#  '2019011709_2019011710',
#  '2018120303_2018120304',
#  '2018110301_2018110302',
#  '2018123119_2018123120',
#  '2018112722_2018112723',
#  '2018123020_2018123021',
#  '2019011906_2019011907',
#  '2019022516_2019022517',
#  '2019021923_2019022000',
#  '2018110418_2018110419',
#  '2018122023_2018122100',
#  '2018100620_2018100621',
#  '2018101623_2018101700',
#  '2018120212_2018120213',
#  '2018112110_2018112111',
#  '2019011005_2019011006',
#  '2018100103_2018100104',
#  '2019012309_2019012310',
#  '2018111322_2018111323',
#  '2019020723_2019020800',
#  '2018120519_2018120520',
#  '2019022823_2019030100',
#  '2019010614_2019010615',
#  '2019021116_2019021117',
#  '2018120420_2018120421',
#  '2019020317_2019020318',
#  '2018121423_2018121500',
#  '2018113018_2018113019',
#  '2018102223_2018102300',
#  '2019012822_2019012823',
#  '2018120104_2018120105',
#  '2019013013_2019013014',
#  '2018111809_2018111810',
#  '2018102115_2018102116',
#  '2019022600_2019022601',
#  '2018121715_2018121716',
#  '2019013102_2019013103',
#  '2019011521_2019011522',
#  '2018110407_2018110408',
#  '2018111606_2018111607',
#  '2019020411_2019020412',
#  '2019010413_2019010414',
#  '2018110914_2018110915',
#  '2018101515_2018101516',
#  '2018100304_2018100305',
#  '2018122315_2018122316',
#  '2019021200_2019021201',
#  '2019012121_2019012122',
#  '2019010502_2019010503',
#  '2018102816_2018102817',
#  '2019020308_2019020309',
#  '2018113007_2018113008',
#  '2018112206_2018112207',
#  '2018100706_2018100707',
#  '2019021602_2019021603',
#  '2018101507_2018101508',
#  '2019011820_2019011821',
#  '2018123106_2018123107',
#  '2019010823_2019010900',
#  '2018122307_2018122308',
#  '2019011008_2019011009',
#  '2019011711_2019011712',
#  '2019011919_2019011920',
#  '2019021713_2019021714',
#  '2018112604_2018112605',
#  '2018100909_2018100910',
#  '2018113015_2018113016',
#  '2019010100_2019010101',
#  '2019020621_2019020622',
#  '2019022202_2019022203',
#  '2018102107_2018102108',
#  '2018120506_2018120507',
#  '2019012408_2019012409',
#  '2018121707_2018121708',
#  '2019021818_2019021819',
#  '2018111204_2018111205',
#  '2019012311_2019012312',
#  '2019022313_2019022314',
#  '2019010323_2019010400',
#  '2018110415_2018110416',
#  '2019020910_2019020911',
#  '2018101814_2018101815',
#  '2018122318_2018122319',
#  '2019011017_2019011018',
#  '2018111720_2018111721',
#  '2019010216_2019010217',
#  '2018101518_2018101519',
#  '2018121902_2018121903',
#  '2018112512_2018112513',
#  '2018100123_2018100200',
#  '2018101201_2018101202',
#  '2019020305_2019020306',
#  '2019021514_2019021515',
#  '2018112403_2018112404',
#  '2018122401_2018122402',
#  '2019012904_2019012905',
#  '2018111811_2018111812',
#  '2018111619_2018111620',
#  '2018121813_2018121814',
#  '2018100410_2018100411',
#  '2019012417_2019012418',
#  '2018121718_2018121719',
#  '2019021807_2019021808',
#  '2018112320_2018112321',
#  '2018111112_2018111113',
#  '2018120921_2018120922',
#  '2018102118_2018102119',
#  '2018100222_2018100223',
#  '2018102601_2018102602',
#  '2018120610_2018120611',
#  '2018112219_2018112220',
#  '2018111003_2018111004',
#  '2018121001_2018121002',
#  '2019022114_2019022115',
#  '2018103010_2018103011',
#  '2019020409_2019020410',
#  '2019012117_2019012118',
#  '2018121218_2018121219',
#  '2018112620_2018112621',
#  '2018111412_2018111413',
#  '2018102418_2018102419',
#  '2018122802_2018122803',
#  '2018100722_2018100723',
#  '2018102301_2018102302',
#  '2018120310_2018120311',
#  '2019011804_2019011805',
#  '2018123122_2018123123',
#  '2018122913_2018122914',
#  '2018112719_2018112720',
#  '2018112911_2018112912',
#  '2019022414_2019022415',
#  '2018121501_2018121502',
#  '2018111503_2018111504',
#  '2019020109_2019020110',
#  '2018122618_2018122619',
#  '2018110223_2018110300',
#  '2019011517_2019011518',
#  '2018111220_2018111221',
#  '2019010716_2019010717',
#  '2018101018_2018101019',
#  '2018112012_2018112013',
#  '2018101701_2018101702',
#  '2019020605_2019020606',
#  '2018122101_2018122102',
#  '2018112103_2018112104',
#  '2019021014_2019021015',
#  '2018111319_2018111320',
#  '2018120522_2018120523',
#  '2018100110_2018100111',
#  '2019020321_2019020322',
#  '2018102407_2018102408',
#  '2019022702_2019022703',
#  '2019012920_2019012921',
#  '2019012108_2019012109',
#  '2018121207_2018121208',
#  '2019022613_2019022614',
#  '2019012819_2019012820',
#  '2019012611_2019012612',
#  '2018111704_2018111705',
#  '2018110115_2018110116',
#  '2019013000_2019013001',
#  '2018100206_2018100207',
#  '2018101007_2018101008',
#  '2019021302_2019021303',
#  '2018110816_2018110817',
#  '2018122607_2018122608',
#  '2019011508_2019011509',
#  '2018112304_2018112305',
#  '2019021213_2019021214',
#  '2019011211_2019011212',
#  '2018120905_2018120906',
#  '2019010400_2019010401',
#  '2018102914_2018102915',
#  '2018123004_2018123005',
#  '2019011922_2019011923',
#  '2019010113_2019010114',
#  '2019020111_2019020112',
#  '2018101015_2018101016',
#  '2018112909_2018112910',
#  '2018100604_2018100605',
#  '2019021700_2019021701',
#  '2018122615_2018122616',
#  '2019012421_2019012422',
#  '2018120917_2018120918',
#  '2019020608_2019020609',
#  '2018112706_2018112707',
#  '2019010901_2019010902',
#  '2019020903_2019020904',
#  '2018120404_2018120405',
#  '2018102415_2018102416',
#  '2018121215_2018121216',
#  '2019022300_2019022301',
#  '2019020812_2019020813',
#  '2019011021_2019011022',
#  '2018101916_2018101917',
#  '2018110107_2018110108',
#  '2018111306_2018111307',
#  '2018121800_2018121801',
#  '2019011505_2019011506',
#  '2018112410_2018112411',
#  '2018100403_2018100404',
#  '2019012609_2019012610',
#  '2018111622_2018111623',
#  '2019010314_2019010315',
#  '2019021416_2019021417',
#  '2018112123_2018112200',
#  '2019012806_2019012807',
#  '2018120120_2018120121',
#  '2018120908_2018120909',
#  '2018100512_2018100513',
#  '2019020617_2019020618',
#  '2018111010_2018111011',
#  '2019012105_2019012106',
#  '2018103003_2018103004',
#  '2018100219_2018100220',
#  '2019011209_2019011210',
#  '2018110601_2018110602',
#  '2018120603_2018120604',
#  '2018112222_2018112223',
#  '2018111523_2018111600',
#  '2019022016_2019022017',
#  '2018110118_2018110119',
#  '2018103112_2018103113',
#  '2018100320_2018100321',
#  '2018120712_2018120713',
#  '2019012002_2019012003',
#  '2019010421_2019010422',
#  '2018111507_2018111508',
#  '2018122917_2018122918',
#  '2019022608_2019022609',
#  '2018110706_2018110707',
#  '2018121004_2018121005',
#  '2019022111_2019022112',
#  '2019012113_2019012114',
#  '2018110909_2018110910',
#  '2018103015_2018103016',
#  '2018102604_2018102605',
#  '2018120615_2018120616',
#  '2019022812_2019022813',
#  '2019013021_2019013022',
#  '2019011402_2019011403',
#  '2019021208_2019021209',
#  '2018112107_2018112108',
#  '2019021511_2019021512',
#  '2019011513_2019011514',
#  '2018122404_2018122405',
#  '2019012901_2019012902',
#  '2018111814_2018111815',
#  '2018100415_2018100416',
#  '2018101204_2018101205',
#  '2019020300_2019020301',
#  '2019010806_2019010807',
#  '2018122120_2018122121',
#  '2018110123_2018110200',
#  '2018111518_2018111519',
#  '2018122908_2018122909',
#  '2019022617_2019022618',
#  '2018102512_2018102513',
#  '2018101720_2018101721',
#  '2018121312_2018121313',
#  '2018110410_2018110411',
#  '2019020915_2019020916',
#  '2018102403_2018102404',
#  '2018101619_2018101620',
#  '2018101811_2018101812',
#  '2019010609_2019010610',
#  '2018121203_2018121204',
#  '2018111201_2018111202',
#  '2019012314_2019012315',
#  '2018122019_2018122020',
#  '2018121520_2018121521',
#  '2019021217_2019021218',
#  '2018101112_2018101113',
#  '2018112118_2018112119',
#  '2018102320_2018102321',
#  '2018122712_2018122713',
#  '2018113010_2018113011',
#  '2019010105_2019010106',
#  '2018102219_2018102220',
#  '2018101003_2018101004',
#  '2018110222_2018110223',
#  '2018121419_2018121420',
#  '2019011714_2019011715',
#  '2018122603_2018122604',
#  '2018112601_2018112602',
#  '2018100301_2018100302',
#  '2018102722_2018102723',
#  '2018122310_2018122311',
#  '2019021205_2019021206',
#  '2019020414_2019020415',
#  '2018121122_2018121123',
#  '2018110911_2018110912',
#  '2018110719_2018110720',
#  '2018120913_2018120914',
#  '2019022109_2019022110',
#  '2018101510_2018101511',
#  '2018111623_2018111700',
#  '2019010117_2019010118',
#  '2018110620_2018110621',
#  '2019011316_2019011317',
#  '2018100418_2018100419',
#  '2018120802_2018120803',
#  '2018101322_2018101323',
#  '2019022605_2019022606',
#  '2018121710_2018121711',
#  '2018122522_2018122523',
#  '2018110103_2018110104',
#  '2018120101_2018120102',
#  '2018102110_2018102111',
#  '2019021509_2019021510',
#  '2018120618_2018120619',
#  '2019020907_2019020908',
#  '2018112223_2018112300',
#  '2019012716_2019012717',
#  '2018121821_2018121822',
#  '2018103018_2018103019',
#  '2019010611_2019010612',
#  '2019010819_2019010820',
#  '2019020613_2019020614',
#  '2018101809_2018101810',
#  '2018112115_2018112116',
#  '2019011000_2019011001',
#  '2018101606_2018101607',
#  '2019020702_2019020703',
#  '2018100407_2018100408',
#  '2019022321_2019022322',
#  '2018122006_2018122007',
#  '2019010920_2019010921',
#  '2019010108_2019010109',
#  '2018110304_2018110305',
#  '2019012400_2019012401',
#  '2018111515_2018111516',
#  '2019021810_2019021811',
#  '2018122905_2018122906',
#  '2018100914_2018100915',
#  '2018102206_2018102207',
#  '2019021721_2019021722',
#  '2018103007_2018103008',
#  '2018112816_2018112817',
#  '2018121406_2018121407',
#  '2018120607_2018120608',
#  '2019020918_2019020919',
#  '2019011406_2019011407',
#  '2019022816_2019022817',
#  '2018110918_2018110919',
#  '2019010607_2019010608',
#  '2018100308_2018100309',
#  '2018111721_2018111722',
#  '2019012905_2019012906',
#  '2018111810_2018111811',
#  '2019021515_2019021516',
#  '2018122400_2018122401',
#  '2018102923_2018103000',
#  '2018100411_2018100412',
#  '2018101200_2018101201',
#  '2019020304_2019020305',
#  '2018120920_2018120921',
#  '2019012006_2019012007',
#  '2018120108_2018120109',
#  '2018112321_2018112322',
#  '2018110702_2018110703',
#  '2018121000_2018121001',
#  '2019022115_2019022116',
#  '2018103011_2018103012',
#  '2018102600_2018102601',
#  '2018120819_2018120820',
#  '2018120611_2018120612',
#  '2018110613_2018110614',
#  '2019011821_2019011822',
#  '2018100317_2018100318',
#  '2018101116_2018101117',
#  '2019022223_2019022300',
#  '2018110907_2018110908',
#  '2019010618_2019010619',
#  '2018122716_2018122717',
#  '2018113014_2018113015',
#  '2019020103_2019020104',
#  '2019010101_2019010102',
#  '2019012522_2019012523',
#  '2018111509_2018111510',
#  '2018100723_2018100800',
#  '2019011710_2019011711',
#  '2018112605_2018112606',
#  '2019010802_2019010803',
#  '2018102516_2018102517',
#  '2018101923_2018102000',
#  '2018120117_2018120118',
#  '2019021623_2019021700',
#  '2018121316_2018121317',
#  '2019020620_2019020621',
#  '2019020719_2019020720',
#  '2019020911_2019020912',
#  '2019010913_2019010914',
#  '2019011122_2019011123',
#  '2018110414_2018110415',
#  '2018101815_2018101816',
#  '2018112109_2018112110',
#  '2018111205_2018111206',
#  '2019012310_2019012311',
#  '2019012603_2019012604',
#  '2019022601_2019022602',
#  '2018121714_2018121715',
#  '2019011419_2019011420',
#  '2019020222_2019020223',
#  '2018120105_2018120106',
#  '2018100409_2018100410',
#  '2018102114_2018102115',
#  '2018101807_2018101808',
#  '2019012712_2019012713',
#  '2019011520_2019011521',
#  '2019022118_2019022119',
#  '2018111217_2018111218',
#  '2018100305_2018100306',
#  '2018120609_2018120610',
#  '2019012019_2019012020',
#  '2018122314_2018122315',
#  '2019011203_2019011204',
#  '2019021201_2019021202',
#  '2018110915_2018110916',
#  '2019020410_2019020411',
#  '2018103009_2018103010',
#  '2018101514_2018101515',
#  '2019011312_2019011313',
#  '2019020123_2019020200',
#  '2019012120_2019012121',
#  '2018120806_2018120807',
#  '2018112617_2018112618',
#  '2019012908_2019012909',
#  '2019021518_2019021519',
#  '2018102313_2018102314',
#  '2018110300_2018110301',
#  '2019021814_2019021815',
#  '2018112903_2018112904',
#  '2018122901_2018122902',
#  '2019012404_2019012405',
#  '2018111511_2018111512',
#  '2018121513_2018121514',
#  '2018100910_2018100911',
#  '2018102202_2018102203',
#  '2019022107_2019022108',
#  '2018111208_2018111209',
#  '2018100621_2018100622',
#  '2018101818_2018101819',
#  '2018121402_2018121403',
#  '2018123021_2018123022',
#  '2018112812_2018112813',
#  '2018101713_2018101714',
#  '2019010615_2019010616',
#  '2018112111_2018112112',
#  '2018122113_2018122114',
#  '2019011004_2019011005',
#  '2019020909_2019020910',
#  '2018112608_2018112609',
#  '2019012917_2019012918',
#  '2018101602_2018101603',
#  '2019021507_2019021508',
#  '2019020706_2019020707',
#  '2018120421_2018120422',
#  '2018122002_2018122003',
#  '2019010712_2019010713',
#  '2018112016_2018112017',
#  '2019021523_2019021600',
#  '2019020118_2019020119',
#  '2018121209_2018121210',
#  '2018101705_2018101706',
#  '2019022222_2019022223',
#  '2019020601_2019020602',
#  '2019010603_2019010604',
#  '2018102409_2018102410',
#  '2018122105_2018122106',
#  '2019021010_2019021011',
#  '2018100114_2018100115',
#  '2019010120_2019010121',
#  '2018122806_2018122807',
#  '2019022123_2019022200',
#  '2018111416_2018111417',
#  '2018110617_2018110618',
#  '2019010908_2019010909',
#  '2018122609_2018122610',
#  '2018102305_2018102306',
#  '2018120314_2018120315',
#  '2019021622_2019021623',
#  '2019022410_2019022411',
#  '2018101009_2018101010',
#  '2018121505_2018121506',
#  '2019011800_2019011801',
#  '2018112915_2018112916',
#  '2018102621_2018102622',
#  '2019020107_2019020108',
#  '2018100202_2018100203',
#  '2019021306_2019021307',
#  '2018121021_2018121022',
#  '2018110812_2018110813',
#  '2018100313_2018100314',
#  '2018112300_2018112301',
#  '2019011215_2019011216',
#  '2019010404_2019010405',
#  '2018120901_2018120902',
#  '2018110903_2018110904',
#  '2018102910_2018102911',
#  '2018101221_2018101222',
#  '2018110608_2018110609',
#  '2019010917_2019010918',
#  '2019022706_2019022707',
#  '2018122421_2018122422',
#  '2019012615_2019012616',
#  '2018111700_2018111701',
#  '2018120113_2018120114',
#  '2018110111_2018110112',
#  '2018121922_2018121923',
#  '2019013004_2019013005',
#  '2018120400_2018120401',
#  '2019010905_2019010906',
#  '2018102411_2018102412',
#  '2018101803_2018101804',
#  '2018100923_2018101000',
#  '2018111213_2018111214',
#  '2018121211_2018121212',
#  '2019022304_2019022305',
#  '2019020816_2019020817',
#  '2018121508_2018121509',
#  '2018101912_2018101913',
#  '2018112918_2018112919',
#  '2019012607_2019012608',
#  '2018102308_2018102309',
#  '2018111302_2018111303',
#  '2018123000_2018123001',
#  '2019020115_2019020116',
#  '2018101011_2018101012',
#  '2018100600_2018100601',
#  '2019021704_2019021705',
#  '2018112613_2018112614',
#  '2018122611_2018122612',
#  '2018122819_2018122820',
#  '2018122920_2018122921',
#  '2019011207_2019011208',
#  '2018122108_2018122109',
#  '2018112702_2018112703',
#  '2018110321_2018110322',
#  '2018101708_2018101709',
#  '2019010522_2019010523',
#  '2019021319_2019021320',
#  '2018111014_2018111015',
#  '2019012101_2019012102',
#  '2019022103_2019022104',
#  '2018102723_2018102800',
#  '2018110605_2018110606',
#  '2019022012_2019022013',
#  '2018102317_2018102318',
#  '2018103116_2018103117',
#  '2018121517_2018121518',
#  '2018112907_2018112908',
#  '2019020223_2019020300',
#  '2019012618_2019012619',
#  '2018120716_2018120717',
#  '2019021220_2019021221',
#  '2019011501_2019011502',
#  '2019021503_2019021504',
#  '2018112414_2018112415',
#  '2019012913_2019012914',
#  '2019022719_2019022720',
#  '2019013122_2019013123',
#  '2018121804_2018121805',
#  '2018110109_2018110110',
#  '2019010310_2019010311',
#  '2019012802_2019012803',
#  '2019021412_2019021413',
#  '2018101717_2018101718',
#  '2018100516_2018100517',
#  '2019011218_2019011219',
#  '2018122117_2018122118',
#  '2019022620_2019022621',
#  '2019011713_2019011714',
#  '2019021711_2019021712',
#  '2019021919_2019021920',
#  '2018122604_2018122605',
#  '2018100615_2018100616',
#  '2018101004_2018101005',
#  '2018123015_2018123016',
#  '2019020100_2019020101',
#  '2019011602_2019011603',
#  '2018102917_2018102918',
#  '2018112307_2018112308',
#  '2019020823_2019020900',
#  '2019021008_2019021009',
#  '2019021820_2019021821',
#  '2018121204_2018121205',
#  '2019012313_2019012314',
#  '2019022311_2019022312',
#  '2019020323_2019020400',
#  '2018102404_2018102405',
#  '2018120415_2018120416',
#  '2019010910_2019010911',
#  '2019010621_2019010622',
#  '2019012202_2019012203',
#  '2019022408_2019022409',
#  '2018111707_2018111708',
#  '2019011818_2019011819',
#  '2018110506_2018110507',
#  '2019010305_2019010306',
#  '2018101203_2018101204',
#  '2018102019_2018102020',
#  '2019013009_2019013010',
#  '2019011514_2019011515',
#  '2018112401_2018112402',
#  '2018122403_2018122404',
#  '2018111813_2018111814',
#  '2018121811_2018121812',
#  '2018121619_2018121620',
#  '2018121720_2018121721',
#  '2019020216_2019020217',
#  '2018112318_2018112319',
#  '2018101312_2018101313',
#  '2019021017_2019021018',
#  '2018102120_2018102121',
#  '2018111902_2018111903',
#  '2018102908_2018102909',
#  '2018122512_2018122513',
#  '2018110610_2018110611',
#  '2018101419_2018101420',
#  '2018102603_2018102604',
#  '2019010409_2019010410',
#  '2018122219_2018122220',
#  '2018111001_2018111002',
#  '2018121003_2018121004',
#  '2019012114_2019012115',
#  '2018122320_2018122321',
#  '2018102712_2018102713',
#  '2019022417_2019022418',
#  '2018111718_2018111719',
#  '2019011807_2019011808',
#  '2018101520_2018101521',
#  '2018121112_2018121113',
#  '2018110921_2018110922',
#  '2018120418_2018120419',
#  '2018112023_2018112100',
#  '2018100802_2018100803',
#  '2019021906_2019021907',
#  '2018113020_2018113021',
#  '2019011923_2019012000',
#  '2019012516_2019012517',
#  '2018110212_2018110213',
#  '2018101122_2018101123',
#  '2018100913_2018100914',
#  '2019022405_2019022406',
#  '2018121510_2018121511',
#  ...]

# %%
a == b
# Out:
# True
